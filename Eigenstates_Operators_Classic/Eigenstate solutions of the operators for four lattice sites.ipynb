# %%
import numpy
import paddle_quantum
from paddle_quantum.qinfo import pauli_str_to_matrix

# Parameters
t = 1
U = 2
N = 8  # Number of qubits
threshold = 1e-4  # Threshold for output coefficients

# Pauli string representation of the Hamiltonian
H_Pauli = [[-t * 0.5, 'X0,X1,I2,I3,I4,I5,I6,I7'], [-t * 0.5, 'Y0,Y1,I2,I3,I4,I5,I6,I7'], 
           [-t * 0.5, 'X0,Z1,Z2,X3,I4,I5,I6,I7'], [-t * 0.5, 'Y0,Z1,Z2,Y3,I4,I5,I6,I7'], 
           [-t * 0.5, 'I0,X1,X2,I3,I4,I5,I6,I7'], [-t * 0.5, 'I0,Y1,Y2,I3,I4,I5,I6,I7'], 
           [-t * 0.5, 'I0,I1,X2,X3,I4,I5,I6,I7'], [-t * 0.5, 'I0,I1,Y2,Y3,I4,I5,I6,I7'], 
           [-t * 0.5, 'I0,I1,I2,I3,X4,X5,I6,I7'], [-t * 0.5, 'I0,I1,I2,I3,Y4,Y5,I6,I7'], 
           [-t * 0.5, 'I0,I1,I2,I3,X4,Z5,Z6,X7'], [-t * 0.5, 'I0,I1,I2,I3,Y4,Z5,Z6,Y7'], 
           [-t * 0.5, 'I0,I1,I2,I3,I4,X5,X6,I7'], [-t * 0.5, 'I0,I1,I2,I3,I4,Y5,Y6,I7'], 
           [-t * 0.5, 'I0,I1,I2,I3,I4,I5,X6,X7'], [-t * 0.5, 'I0,I1,I2,I3,I4,I5,Y6,Y7'], 
           [U * 0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-U * 0.25, 'I0,I1,I2,I3,Z4,I5,I6,I7'], 
           [-U * 0.25, 'Z0,I1,I2,I3,I4,I5,I6,I7'], [U * 0.25, 'Z0,I1,I2,I3,Z4,I5,I6,I7'], 
           [U * 0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-U * 0.25, 'I0,I1,I2,I3,I4,Z5,I6,I7'], 
           [-U * 0.25, 'I0,Z1,I2,I3,I4,I5,I6,I7'], [U * 0.25, 'I0,Z1,I2,I3,I4,Z5,I6,I7'], 
           [U * 0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-U * 0.25, 'I0,I1,I2,I3,I4,I5,Z6,I7'], 
           [-U * 0.25, 'I0,I1,Z2,I3,I4,I5,I6,I7'], [U * 0.25, 'I0,I1,Z2,I3,I4,I5,Z6,I7'], 
           [U * 0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-U * 0.25, 'I0,I1,I2,I3,I4,I5,I6,Z7'], 
           [-U * 0.25, 'I0,I1,I2,Z3,I4,I5,I6,I7'], [U * 0.25, 'I0,I1,I2,Z3,I4,I5,I6,Z7']]

# Define computational basis
basis = numpy.eye(2**N)

# Take the dagger
basis_dagger = numpy.array([numpy.conj(basis[i]).T for i in range(2**N)])

# Matrix form
H_matrix = pauli_str_to_matrix(H_Pauli, N).astype(paddle_quantum.get_dtype())

# Calculate the eigenvalues and eigenvectors of the H matrix
eigenvalues, eigenvectors = numpy.linalg.eigh(H_matrix)

# Express each eigenstate as a linear combination of computational basis states
for i in range(2**N):
    print(f"Energy eigenstate |E{i}> corresponds to eigenvalue: {eigenvalues[i]}")
    print("Representation in the computational basis:")
    first = True   # Set the first nonzero term without a plus sign
    for j in range(2**N):
        coefficient = numpy.dot(basis_dagger[j], eigenvectors[:, i])
        if abs(coefficient) > threshold:
            if first:
                print(f"{coefficient} * |{format(j, f'0{N}b')}>")
                first = False
            else:
                print(f"+ {coefficient} * |{format(j, f'0{N}b')}>")
# Out:
# Energy eigenstate |E0> corresponds to eigenvalue: -3.6272130012512207
# Representation in the computational basis:
# (0.1842399537563324+0j) * |00010001>
# + (0.2591893672943115+0j) * |00010010>
# + (0.28582754731178284+0j) * |00010100>
# + (0.2591893672943115+0j) * |00011000>
# + (0.2591893672943115+0j) * |00100001>
# + (0.1842399537563324+0j) * |00100010>
# + (0.2591893672943115+0j) * |00100100>
# + (0.28582754731178284+0j) * |00101000>
# + (0.28582754731178284+0j) * |01000001>
# + (0.2591893672943115+0j) * |01000010>
# + (0.1842399537563324+0j) * |01000100>
# + (0.2591893672943115+0j) * |01001000>
# + (0.2591893672943115+0j) * |10000001>
# + (0.28582754731178284+0j) * |10000010>
# + (0.2591893672943115+0j) * |10000100>
# + (0.1842399537563324+0j) * |10001000>
# Energy eigenstate |E1> corresponds to eigenvalue: -3.2092514038085938
# Representation in the computational basis:
# (0.014013870619237423+0j) * |00110001>
# + (-0.008351783268153667+0j) * |00110010>
# + (0.02274729125201702+0j) * |00110100>
# + (-0.013556599617004395+0j) * |00111000>
# + (-0.19580182433128357+0j) * |01010001>
# + (-0.2820690870285034+0j) * |01010010>
# + (-0.19580182433128357+0j) * |01010100>
# + (-0.2820690870285034+0j) * |01011000>
# + (-0.3048163652420044+0j) * |01100001>
# + (-0.18745003640651703+0j) * |01100010>
# + (-0.1877875179052353+0j) * |01100100>
# + (-0.30426856875419617+0j) * |01101000>
# + (-0.1877875179052353+0j) * |10010001>
# + (-0.30426856875419617+0j) * |10010010>
# + (-0.3048163652420044+0j) * |10010100>
# + (-0.18745003640651703+0j) * |10011000>
# + (-0.2907119691371918+0j) * |10100001>
# + (-0.2018013894557953+0j) * |10100010>
# + (-0.2907119691371918+0j) * |10100100>
# + (-0.2018013894557953+0j) * |10101000>
# + (-0.02274729125201702+0j) * |11000001>
# + (0.013556599617004395+0j) * |11000010>
# + (-0.014013870619237423+0j) * |11000100>
# + (0.008351783268153667+0j) * |11001000>
# Energy eigenstate |E2> corresponds to eigenvalue: -3.2092514038085938
# Representation in the computational basis:
# (0.17265978455543518+0j) * |00010011>
# + (0.08829638361930847+0j) * |00010101>
# + (-0.15306265652179718+0j) * |00010110>
# + (-0.09429695457220078+0j) * |00011001>
# + (-0.3845737874507904+0j) * |00011010>
# + (-0.2802610695362091+0j) * |00011100>
# + (0.16260993480682373+0j) * |00100011>
# + (0.12719841301441193+0j) * |00100101>
# + (-0.07431354373693466+0j) * |00100110>
# + (-0.12062561511993408+0j) * |00101001>
# + (-0.26695674657821655+0j) * |00101010>
# + (-0.2639481723308563+0j) * |00101100>
# + (0.2802610695362091+0j) * |01000011>
# + (0.08829638361930847+0j) * |01000101>
# + (-0.09429695457220078+0j) * |01000110>
# + (-0.15306265652179718+0j) * |01001001>
# + (-0.3845737874507904+0j) * |01001010>
# + (-0.17265978455543518+0j) * |01001100>
# + (0.2639481723308563+0j) * |10000011>
# + (0.12719841301441193+0j) * |10000101>
# + (-0.12062561511993408+0j) * |10000110>
# + (-0.07431354373693466+0j) * |10001001>
# + (-0.26695674657821655+0j) * |10001010>
# + (-0.16260993480682373+0j) * |10001100>
# Energy eigenstate |E3> corresponds to eigenvalue: -3.2092514038085938
# Representation in the computational basis:
# (-0.07431354373693466+0j) * |00010011>
# + (-0.26695674657821655+0j) * |00010101>
# + (-0.2639481723308563+0j) * |00010110>
# + (-0.16260993480682373+0j) * |00011001>
# + (-0.12719841301441193+0j) * |00011010>
# + (0.12062561511993408+0j) * |00011100>
# + (-0.09429695457220078+0j) * |00100011>
# + (-0.3845737874507904+0j) * |00100101>
# + (-0.17265978455543518+0j) * |00100110>
# + (-0.2802610695362091+0j) * |00101001>
# + (-0.08829638361930847+0j) * |00101010>
# + (0.15306265652179718+0j) * |00101100>
# + (-0.12062561511993408+0j) * |01000011>
# + (-0.26695674657821655+0j) * |01000101>
# + (-0.16260993480682373+0j) * |01000110>
# + (-0.2639481723308563+0j) * |01001001>
# + (-0.12719841301441193+0j) * |01001010>
# + (0.07431354373693466+0j) * |01001100>
# + (-0.15306265652179718+0j) * |10000011>
# + (-0.3845737874507904+0j) * |10000101>
# + (-0.2802610695362091+0j) * |10000110>
# + (-0.17265978455543518+0j) * |10001001>
# + (-0.08829638361930847+0j) * |10001010>
# + (0.09429695457220078+0j) * |10001100>
# Energy eigenstate |E4> corresponds to eigenvalue: -3.2092514038085938
# Representation in the computational basis:
# (-0.18745003640651703+0j) * |00110001>
# + (-0.1877875179052353+0j) * |00110010>
# + (-0.30426856875419617+0j) * |00110100>
# + (-0.3048163652420044+0j) * |00111000>
# + (-0.2018013894557953+0j) * |01010001>
# + (-0.2907119691371918+0j) * |01010010>
# + (-0.2018013894557953+0j) * |01010100>
# + (-0.2907119691371918+0j) * |01011000>
# + (0.013556599617004395+0j) * |01100001>
# + (-0.014013870619237423+0j) * |01100010>
# + (0.008351783268153667+0j) * |01100100>
# + (-0.02274729125201702+0j) * |01101000>
# + (0.008351783268153667+0j) * |10010001>
# + (-0.02274729125201702+0j) * |10010010>
# + (0.013556599617004395+0j) * |10010100>
# + (-0.014013870619237423+0j) * |10011000>
# + (0.2820690870285034+0j) * |10100001>
# + (0.19580182433128357+0j) * |10100010>
# + (0.2820690870285034+0j) * |10100100>
# + (0.19580182433128357+0j) * |10101000>
# + (0.30426856875419617+0j) * |11000001>
# + (0.3048163652420044+0j) * |11000010>
# + (0.18745003640651703+0j) * |11000100>
# + (0.1877875179052353+0j) * |11001000>
# Energy eigenstate |E5> corresponds to eigenvalue: -2.8284270763397217
# Representation in the computational basis:
# (0.09107160568237305+0j) * |00110011>
# + (0.15546895563602448+0j) * |00110101>
# + (-0.15546895563602448+0j) * |00111010>
# + (-0.2198663055896759+0j) * |00111100>
# + (0.15546895563602448+0j) * |01010011>
# + (-0.15546895563602448+0j) * |01010110>
# + (-0.15546895563602448+0j) * |01011001>
# + (-0.4397326111793518+0j) * |01011010>
# + (-0.15546895563602448+0j) * |01011100>
# + (-0.15546895563602448+0j) * |01100101>
# + (-0.09107160568237305+0j) * |01100110>
# + (-0.2198663055896759+0j) * |01101001>
# + (-0.15546895563602448+0j) * |01101010>
# + (-0.15546895563602448+0j) * |10010101>
# + (-0.2198663055896759+0j) * |10010110>
# + (-0.09107160568237305+0j) * |10011001>
# + (-0.15546895563602448+0j) * |10011010>
# + (-0.15546895563602448+0j) * |10100011>
# + (-0.4397326111793518+0j) * |10100101>
# + (-0.15546895563602448+0j) * |10100110>
# + (-0.15546895563602448+0j) * |10101001>
# + (0.15546895563602448+0j) * |10101100>
# + (-0.2198663055896759+0j) * |11000011>
# + (-0.15546895563602448+0j) * |11000101>
# + (0.15546895563602448+0j) * |11001010>
# + (0.09107160568237305+0j) * |11001100>
# Energy eigenstate |E6> corresponds to eigenvalue: -2.6858460903167725
# Representation in the computational basis:
# (-0.22480887174606323+0j) * |01110001>
# + (-0.19190460443496704+0j) * |01110010>
# + (-0.22480887174606323+0j) * |01110100>
# + (-0.33480527997016907+0j) * |01111000>
# + (-0.19190460443496704+0j) * |10110001>
# + (-0.22480887174606323+0j) * |10110010>
# + (-0.33480527997016907+0j) * |10110100>
# + (-0.22480887174606323+0j) * |10111000>
# + (-0.22480887174606323+0j) * |11010001>
# + (-0.33480527997016907+0j) * |11010010>
# + (-0.22480887174606323+0j) * |11010100>
# + (-0.19190460443496704+0j) * |11011000>
# + (-0.33480527997016907+0j) * |11100001>
# + (-0.22480887174606323+0j) * |11100010>
# + (-0.19190460443496704+0j) * |11100100>
# + (-0.22480887174606323+0j) * |11101000>
# Energy eigenstate |E7> corresponds to eigenvalue: -2.6858460903167725
# Representation in the computational basis:
# (-0.1589638739824295+0j) * |00110101>
# + (-0.13569705188274384+0j) * |00110110>
# + (-0.13569705188274384+0j) * |00111001>
# + (-0.1589638739824295+0j) * |00111010>
# + (0.1589638739824295+0j) * |01010011>
# + (-0.1589638739824295+0j) * |01010110>
# + (-0.1589638739824295+0j) * |01011001>
# + (-0.47348615527153015+0j) * |01011010>
# + (-0.1589638739824295+0j) * |01011100>
# + (0.13569705188274384+0j) * |01100011>
# + (0.1589638739824295+0j) * |01100101>
# + (-0.1589638739824295+0j) * |01101010>
# + (-0.13569705188274384+0j) * |01101100>
# + (0.13569705188274384+0j) * |10010011>
# + (0.1589638739824295+0j) * |10010101>
# + (-0.1589638739824295+0j) * |10011010>
# + (-0.13569705188274384+0j) * |10011100>
# + (0.1589638739824295+0j) * |10100011>
# + (0.47348615527153015+0j) * |10100101>
# + (0.1589638739824295+0j) * |10100110>
# + (0.1589638739824295+0j) * |10101001>
# + (-0.1589638739824295+0j) * |10101100>
# + (0.1589638739824295+0j) * |11000101>
# + (0.13569705188274384+0j) * |11000110>
# + (0.13569705188274384+0j) * |11001001>
# + (0.1589638739824295+0j) * |11001010>
# Energy eigenstate |E8> corresponds to eigenvalue: -2.6858460903167725
# Representation in the computational basis:
# (0.22480887174606323+0j) * |00010111>
# + (0.19190460443496704+0j) * |00011011>
# + (0.22480887174606323+0j) * |00011101>
# + (0.33480527997016907+0j) * |00011110>
# + (0.19190460443496704+0j) * |00100111>
# + (0.22480887174606323+0j) * |00101011>
# + (0.33480527997016907+0j) * |00101101>
# + (0.22480887174606323+0j) * |00101110>
# + (0.22480887174606323+0j) * |01000111>
# + (0.33480527997016907+0j) * |01001011>
# + (0.22480887174606323+0j) * |01001101>
# + (0.19190460443496704+0j) * |01001110>
# + (0.33480527997016907+0j) * |10000111>
# + (0.22480887174606323+0j) * |10001011>
# + (0.19190460443496704+0j) * |10001101>
# + (0.22480887174606323+0j) * |10001110>
# Energy eigenstate |E9> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (0.015017877332866192+0j) * |00010010>
# + (0.03932461887598038+0j) * |00010100>
# + (-0.006756957154721022+0j) * |00010110>
# + (0.02430674061179161+0j) * |00011000>
# + (-0.006756957154721022+0j) * |00011010>
# + (-0.006756957154721022+0j) * |00011100>
# + (-0.015017877332866192+0j) * |00100001>
# + (0.02430674061179161+0j) * |00100100>
# + (0.006756957154721022+0j) * |00100101>
# + (0.009288863278925419+0j) * |00101000>
# + (0.006756957154721022+0j) * |00101001>
# + (-0.006756957154721022+0j) * |00101100>
# + (-0.16258008778095245+0j) * |00110000>
# + (-0.014923985116183758+0j) * |00110011>
# + (-0.04430349916219711+0j) * |00110100>
# + (-0.02238597720861435+0j) * |00110101>
# + (-0.04430349916219711+0j) * |00111000>
# + (0.02238597720861435+0j) * |00111010>
# + (0.0447719544172287+0j) * |00111100>
# + (-0.03932461887598038+0j) * |01000001>
# + (-0.02430674061179161+0j) * |01000010>
# + (-0.006756957154721022+0j) * |01000011>
# + (-0.015017877332866192+0j) * |01001000>
# + (0.006756957154721022+0j) * |01001001>
# + (0.006756957154721022+0j) * |01001010>
# + (-0.23424643278121948+0j) * |01010000>
# + (0.04430349916219711+0j) * |01010010>
# + (-0.02238597720861435+0j) * |01010011>
# + (-0.029847970232367516+0j) * |01010101>
# + (-0.02238597720861435+0j) * |01010110>
# + (-0.04430349916219711+0j) * |01011000>
# + (-0.02238597720861435+0j) * |01011001>
# + (0.02238597720861435+0j) * |01011100>
# + (-0.07166633754968643+0j) * |01100000>
# + (-0.04430349916219711+0j) * |01100001>
# + (-0.02238597720861435+0j) * |01100101>
# + (-0.014923985116183758+0j) * |01100110>
# + (-0.04430349916219711+0j) * |01101000>
# + (-0.0447719544172287+0j) * |01101001>
# + (-0.02238597720861435+0j) * |01101010>
# + (-0.45397835969924927+0j) * |01110000>
# + (-0.02430674061179161+0j) * |10000001>
# + (-0.009288863278925419+0j) * |10000010>
# + (-0.006756957154721022+0j) * |10000011>
# + (0.015017877332866192+0j) * |10000100>
# + (-0.006756957154721022+0j) * |10000101>
# + (-0.006756957154721022+0j) * |10000110>
# + (-0.07166633754968643+0j) * |10010000>
# + (0.04430349916219711+0j) * |10010010>
# + (0.04430349916219711+0j) * |10010100>
# + (-0.02238597720861435+0j) * |10010101>
# + (-0.0447719544172287+0j) * |10010110>
# + (-0.014923985116183758+0j) * |10011001>
# + (-0.02238597720861435+0j) * |10011010>
# + (0.09091375023126602+0j) * |10100000>
# + (-0.04430349916219711+0j) * |10100001>
# + (0.02238597720861435+0j) * |10100011>
# + (0.04430349916219711+0j) * |10100100>
# + (-0.02238597720861435+0j) * |10100110>
# + (-0.02238597720861435+0j) * |10101001>
# + (-0.029847970232367516+0j) * |10101010>
# + (-0.02238597720861435+0j) * |10101100>
# + (-0.45397835969924927+0j) * |10110000>
# + (0.16258008778095245+0j) * |11000000>
# + (-0.04430349916219711+0j) * |11000001>
# + (-0.04430349916219711+0j) * |11000010>
# + (0.0447719544172287+0j) * |11000011>
# + (0.02238597720861435+0j) * |11000101>
# + (-0.02238597720861435+0j) * |11001010>
# + (-0.014923985116183758+0j) * |11001100>
# + (-0.45397835969924927+0j) * |11010000>
# + (-0.45397835969924927+0j) * |11100000>
# Energy eigenstate |E10> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.1727583110332489+0j) * |00010010>
# + (-0.45237115025520325+0j) * |00010100>
# + (0.07772871851921082+0j) * |00010110>
# + (-0.27961283922195435+0j) * |00011000>
# + (0.07772871851921082+0j) * |00011010>
# + (0.07772871851921082+0j) * |00011100>
# + (0.1727583110332489+0j) * |00100001>
# + (-0.27961283922195435+0j) * |00100100>
# + (-0.07772871851921082+0j) * |00100101>
# + (-0.10685453563928604+0j) * |00101000>
# + (-0.07772871851921082+0j) * |00101001>
# + (0.07772871851921082+0j) * |00101100>
# + (-0.12576287984848022+0j) * |00110000>
# + (0.0001862674398580566+0j) * |00110011>
# + (0.00023063943081069738+0j) * |00110100>
# + (0.0002794011670630425+0j) * |00110101>
# + (0.00023063943081069738+0j) * |00111000>
# + (-0.0002794011670630425+0j) * |00111010>
# + (-0.000558802334126085+0j) * |00111100>
# + (0.45237115025520325+0j) * |01000001>
# + (0.27961283922195435+0j) * |01000010>
# + (0.07772871851921082+0j) * |01000011>
# + (0.1727583110332489+0j) * |01001000>
# + (-0.07772871851921082+0j) * |01001001>
# + (-0.07772871851921082+0j) * |01001010>
# + (-0.12576287984848022+0j) * |01010000>
# + (-0.00023063943081069738+0j) * |01010010>
# + (0.0002794011670630425+0j) * |01010011>
# + (0.0003725348797161132+0j) * |01010101>
# + (0.0002794011670630425+0j) * |01010110>
# + (0.00023063943081069738+0j) * |01011000>
# + (0.0002794011670630425+0j) * |01011001>
# + (-0.0002794011670630425+0j) * |01011100>
# + (0.00023063943081069738+0j) * |01100001>
# + (0.0002794011670630425+0j) * |01100101>
# + (0.0001862674398580566+0j) * |01100110>
# + (0.00023063943081069738+0j) * |01101000>
# + (0.000558802334126085+0j) * |01101001>
# + (0.0002794011670630425+0j) * |01101010>
# + (0.27961283922195435+0j) * |10000001>
# + (0.10685453563928604+0j) * |10000010>
# + (0.07772871851921082+0j) * |10000011>
# + (-0.1727583110332489+0j) * |10000100>
# + (0.07772871851921082+0j) * |10000101>
# + (0.07772871851921082+0j) * |10000110>
# + (-0.00023063943081069738+0j) * |10010010>
# + (-0.00023063943081069738+0j) * |10010100>
# + (0.0002794011670630425+0j) * |10010101>
# + (0.000558802334126085+0j) * |10010110>
# + (0.0001862674398580566+0j) * |10011001>
# + (0.0002794011670630425+0j) * |10011010>
# + (0.12576287984848022+0j) * |10100000>
# + (0.00023063943081069738+0j) * |10100001>
# + (-0.0002794011670630425+0j) * |10100011>
# + (-0.00023063943081069738+0j) * |10100100>
# + (0.0002794011670630425+0j) * |10100110>
# + (0.0002794011670630425+0j) * |10101001>
# + (0.0003725348797161132+0j) * |10101010>
# + (0.0002794011670630425+0j) * |10101100>
# + (0.12576287984848022+0j) * |11000000>
# + (0.00023063943081069738+0j) * |11000001>
# + (0.00023063943081069738+0j) * |11000010>
# + (-0.000558802334126085+0j) * |11000011>
# + (-0.0002794011670630425+0j) * |11000101>
# + (0.0002794011670630425+0j) * |11001010>
# + (0.0001862674398580566+0j) * |11001100>
# Energy eigenstate |E11> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.004657197277992964+0j) * |00010010>
# + (-0.012194965966045856+0j) * |00010100>
# + (0.0020954012870788574+0j) * |00010110>
# + (-0.007537768688052893+0j) * |00011000>
# + (0.0020954012870788574+0j) * |00011010>
# + (0.0020954012870788574+0j) * |00011100>
# + (0.004657197277992964+0j) * |00100001>
# + (-0.007537768688052893+0j) * |00100100>
# + (-0.0020954012870788574+0j) * |00100101>
# + (-0.0028805716428905725+0j) * |00101000>
# + (-0.0020954012870788574+0j) * |00101001>
# + (0.0020954012870788574+0j) * |00101100>
# + (0.05190461501479149+0j) * |00110000>
# + (0.08126688748598099+0j) * |00110011>
# + (-0.1492699533700943+0j) * |00110100>
# + (0.12190032750368118+0j) * |00110101>
# + (-0.1492699533700943+0j) * |00111000>
# + (-0.12190032750368118+0j) * |00111010>
# + (-0.24380065500736237+0j) * |00111100>
# + (0.012194965966045856+0j) * |01000001>
# + (0.007537768688052893+0j) * |01000010>
# + (0.0020954012870788574+0j) * |01000011>
# + (0.004657197277992964+0j) * |01001000>
# + (-0.0020954012870788574+0j) * |01001001>
# + (-0.0020954012870788574+0j) * |01001010>
# + (-0.1520579606294632+0j) * |01010000>
# + (0.1492699533700943+0j) * |01010010>
# + (0.12190032750368118+0j) * |01010011>
# + (0.16253377497196198+0j) * |01010101>
# + (0.12190032750368118+0j) * |01010110>
# + (-0.1492699533700943+0j) * |01011000>
# + (0.12190032750368118+0j) * |01011001>
# + (-0.12190032750368118+0j) * |01011100>
# + (-0.20396257936954498+0j) * |01100000>
# + (-0.1492699533700943+0j) * |01100001>
# + (0.12190032750368118+0j) * |01100101>
# + (0.08126688748598099+0j) * |01100110>
# + (-0.1492699533700943+0j) * |01101000>
# + (0.24380065500736237+0j) * |01101001>
# + (0.12190032750368118+0j) * |01101010>
# + (0.007537768688052893+0j) * |10000001>
# + (0.0028805716428905725+0j) * |10000010>
# + (0.0020954012870788574+0j) * |10000011>
# + (-0.004657197277992964+0j) * |10000100>
# + (0.0020954012870788574+0j) * |10000101>
# + (0.0020954012870788574+0j) * |10000110>
# + (-0.20396257936954498+0j) * |10010000>
# + (0.1492699533700943+0j) * |10010010>
# + (0.1492699533700943+0j) * |10010100>
# + (0.12190032750368118+0j) * |10010101>
# + (0.24380065500736237+0j) * |10010110>
# + (0.08126688748598099+0j) * |10011001>
# + (0.12190032750368118+0j) * |10011010>
# + (-0.2558671832084656+0j) * |10100000>
# + (-0.1492699533700943+0j) * |10100001>
# + (-0.12190032750368118+0j) * |10100011>
# + (0.1492699533700943+0j) * |10100100>
# + (0.12190032750368118+0j) * |10100110>
# + (0.12190032750368118+0j) * |10101001>
# + (0.16253377497196198+0j) * |10101010>
# + (0.12190032750368118+0j) * |10101100>
# + (-0.05190461501479149+0j) * |11000000>
# + (-0.1492699533700943+0j) * |11000001>
# + (-0.1492699533700943+0j) * |11000010>
# + (-0.24380065500736237+0j) * |11000011>
# + (-0.12190032750368118+0j) * |11000101>
# + (0.12190032750368118+0j) * |11001010>
# + (0.08126688748598099+0j) * |11001100>
# Energy eigenstate |E12> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.49755606055259705+0j) * |00000011>
# + (-0.448180228471756+0j) * |00000101>
# + (0.04937583953142166+0j) * |00000110>
# + (0.04937583953142166+0j) * |00001001>
# + (0.5469319224357605+0j) * |00001010>
# + (0.49755606055259705+0j) * |00001100>
# Energy eigenstate |E13> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.5+0j) * |00000001>
# + (-0.5+0j) * |00000010>
# + (-0.5+0j) * |00000100>
# + (-0.5+0j) * |00001000>
# Energy eigenstate |E14> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (0.5+0j) * |00000111>
# + (0.5+0j) * |00001011>
# + (0.5+0j) * |00001101>
# + (0.5+0j) * |00001110>
# Energy eigenstate |E15> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (0.014554930850863457+0j) * |00010010>
# + (0.03811238333582878+0j) * |00010100>
# + (-0.006548664532601833+0j) * |00010110>
# + (0.023557452484965324+0j) * |00011000>
# + (-0.006548664532601833+0j) * |00011010>
# + (-0.006548664532601833+0j) * |00011100>
# + (-0.014554930850863457+0j) * |00100001>
# + (0.023557452484965324+0j) * |00100100>
# + (0.006548664532601833+0j) * |00100101>
# + (0.009002521634101868+0j) * |00101000>
# + (0.006548664532601833+0j) * |00101001>
# + (-0.006548664532601833+0j) * |00101100>
# + (-0.15806622803211212+0j) * |00110000>
# + (-0.04031728208065033+0j) * |00110011>
# + (0.012723294086754322+0j) * |00110100>
# + (-0.060475923120975494+0j) * |00110101>
# + (0.012723294086754322+0j) * |00111000>
# + (0.060475923120975494+0j) * |00111010>
# + (0.12095184624195099+0j) * |00111100>
# + (-0.03811238333582878+0j) * |01000001>
# + (-0.023557452484965324+0j) * |01000010>
# + (-0.006548664532601833+0j) * |01000011>
# + (-0.014554930850863457+0j) * |01001000>
# + (0.006548664532601833+0j) * |01001001>
# + (0.006548664532601833+0j) * |01001010>
# + (-0.5661779642105103+0j) * |01010000>
# + (-0.012723294086754322+0j) * |01010010>
# + (-0.060475923120975494+0j) * |01010011>
# + (-0.08063456416130066+0j) * |01010101>
# + (-0.060475923120975494+0j) * |01010110>
# + (0.012723294086754322+0j) * |01011000>
# + (-0.060475923120975494+0j) * |01011001>
# + (0.060475923120975494+0j) * |01011100>
# + (-0.40811172127723694+0j) * |01100000>
# + (0.012723294086754322+0j) * |01100001>
# + (-0.060475923120975494+0j) * |01100101>
# + (-0.04031728208065033+0j) * |01100110>
# + (0.012723294086754322+0j) * |01101000>
# + (-0.12095184624195099+0j) * |01101001>
# + (-0.060475923120975494+0j) * |01101010>
# + (0.14891886711120605+0j) * |01110000>
# + (-0.023557452484965324+0j) * |10000001>
# + (-0.009002521634101868+0j) * |10000010>
# + (-0.006548664532601833+0j) * |10000011>
# + (0.014554930850863457+0j) * |10000100>
# + (-0.006548664532601833+0j) * |10000101>
# + (-0.006548664532601833+0j) * |10000110>
# + (-0.40811172127723694+0j) * |10010000>
# + (-0.012723294086754322+0j) * |10010010>
# + (-0.012723294086754322+0j) * |10010100>
# + (-0.060475923120975494+0j) * |10010101>
# + (-0.12095184624195099+0j) * |10010110>
# + (-0.04031728208065033+0j) * |10011001>
# + (-0.060475923120975494+0j) * |10011010>
# + (-0.250045508146286+0j) * |10100000>
# + (0.012723294086754322+0j) * |10100001>
# + (0.060475923120975494+0j) * |10100011>
# + (-0.012723294086754322+0j) * |10100100>
# + (-0.060475923120975494+0j) * |10100110>
# + (-0.060475923120975494+0j) * |10101001>
# + (-0.08063456416130066+0j) * |10101010>
# + (-0.060475923120975494+0j) * |10101100>
# + (0.14891886711120605+0j) * |10110000>
# + (0.15806622803211212+0j) * |11000000>
# + (0.012723294086754322+0j) * |11000001>
# + (0.012723294086754322+0j) * |11000010>
# + (0.12095184624195099+0j) * |11000011>
# + (0.060475923120975494+0j) * |11000101>
# + (-0.060475923120975494+0j) * |11001010>
# + (-0.04031728208065033+0j) * |11001100>
# + (0.14891886711120605+0j) * |11010000>
# + (0.14891886711120605+0j) * |11100000>
# Energy eigenstate |E16> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.003082506125792861+0j) * |00010010>
# + (0.11256709694862366+0j) * |00010100>
# + (0.2727827727794647+0j) * |00010110>
# + (0.11564960330724716+0j) * |00011000>
# + (0.2727827727794647+0j) * |00011010>
# + (0.2727827727794647+0j) * |00011100>
# + (0.003082506125792861+0j) * |00100001>
# + (0.11564960330724716+0j) * |00100100>
# + (-0.2727827727794647+0j) * |00100101>
# + (0.11873210966587067+0j) * |00101000>
# + (-0.2727827727794647+0j) * |00101001>
# + (0.2727827727794647+0j) * |00101100>
# + (-0.11256709694862366+0j) * |01000001>
# + (-0.11564960330724716+0j) * |01000010>
# + (0.2727827727794647+0j) * |01000011>
# + (0.003082506125792861+0j) * |01001000>
# + (-0.2727827727794647+0j) * |01001001>
# + (-0.2727827727794647+0j) * |01001010>
# + (-0.11564960330724716+0j) * |10000001>
# + (-0.11873210966587067+0j) * |10000010>
# + (0.2727827727794647+0j) * |10000011>
# + (-0.003082506125792861+0j) * |10000100>
# + (0.2727827727794647+0j) * |10000101>
# + (0.2727827727794647+0j) * |10000110>
# Energy eigenstate |E17> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.30517083406448364+0j) * |00010010>
# + (-0.13735796511173248+0j) * |00010100>
# + (-0.049729883670806885+0j) * |00010110>
# + (0.16781288385391235+0j) * |00011000>
# + (-0.049729883670806885+0j) * |00011010>
# + (-0.049729883670806885+0j) * |00011100>
# + (0.30517083406448364+0j) * |00100001>
# + (0.16781288385391235+0j) * |00100100>
# + (0.049729883670806885+0j) * |00100101>
# + (0.472983717918396+0j) * |00101000>
# + (0.049729883670806885+0j) * |00101001>
# + (-0.049729883670806885+0j) * |00101100>
# + (0.13735796511173248+0j) * |01000001>
# + (-0.16781288385391235+0j) * |01000010>
# + (-0.049729883670806885+0j) * |01000011>
# + (0.30517083406448364+0j) * |01001000>
# + (0.049729883670806885+0j) * |01001001>
# + (0.049729883670806885+0j) * |01001010>
# + (-0.16781288385391235+0j) * |10000001>
# + (-0.472983717918396+0j) * |10000010>
# + (-0.049729883670806885+0j) * |10000011>
# + (-0.30517083406448364+0j) * |10000100>
# + (-0.049729883670806885+0j) * |10000101>
# + (-0.049729883670806885+0j) * |10000110>
# Energy eigenstate |E18> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.5+0j) * |00010000>
# + (-0.5+0j) * |00100000>
# + (-0.5+0j) * |01000000>
# + (-0.5+0j) * |10000000>
# Energy eigenstate |E19> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.04937583953142166+0j) * |00000011>
# + (-0.5469319224357605+0j) * |00000101>
# + (-0.49755606055259705+0j) * |00000110>
# + (-0.49755606055259705+0j) * |00001001>
# + (-0.448180228471756+0j) * |00001010>
# + (0.04937583953142166+0j) * |00001100>
# Energy eigenstate |E20> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (0.03154871240258217+0j) * |00010010>
# + (0.08261094242334366+0j) * |00010100>
# + (-0.01419463474303484+0j) * |00010110>
# + (0.05106223374605179+0j) * |00011000>
# + (-0.01419463474303484+0j) * |00011010>
# + (-0.01419463474303484+0j) * |00011100>
# + (-0.03154871240258217+0j) * |00100001>
# + (0.05106223374605179+0j) * |00100100>
# + (0.01419463474303484+0j) * |00100101>
# + (0.01951352134346962+0j) * |00101000>
# + (0.01419463474303484+0j) * |00101001>
# + (-0.01419463474303484+0j) * |00101100>
# + (-0.3410360813140869+0j) * |00110000>
# + (-0.005231753922998905+0j) * |00110011>
# + (-0.1493048369884491+0j) * |00110100>
# + (-0.00784763041883707+0j) * |00110101>
# + (-0.1493048369884491+0j) * |00111000>
# + (0.00784763041883707+0j) * |00111010>
# + (0.01569526083767414+0j) * |00111100>
# + (-0.08261094242334366+0j) * |01000001>
# + (-0.05106223374605179+0j) * |01000010>
# + (-0.01419463474303484+0j) * |01000011>
# + (-0.03154871240258217+0j) * |01001000>
# + (0.01419463474303484+0j) * |01001001>
# + (0.01419463474303484+0j) * |01001010>
# + (-0.14944496750831604+0j) * |01010000>
# + (0.1493048369884491+0j) * |01010010>
# + (-0.00784763041883707+0j) * |01010011>
# + (-0.01046350784599781+0j) * |01010101>
# + (-0.00784763041883707+0j) * |01010110>
# + (-0.1493048369884491+0j) * |01011000>
# + (-0.00784763041883707+0j) * |01011001>
# + (0.00784763041883707+0j) * |01011100>
# + (0.19159111380577087+0j) * |01100000>
# + (-0.1493048369884491+0j) * |01100001>
# + (-0.00784763041883707+0j) * |01100101>
# + (-0.005231753922998905+0j) * |01100110>
# + (-0.1493048369884491+0j) * |01101000>
# + (-0.01569526083767414+0j) * |01101001>
# + (-0.00784763041883707+0j) * |01101010>
# + (0.14740023016929626+0j) * |01110000>
# + (-0.05106223374605179+0j) * |10000001>
# + (-0.01951352134346962+0j) * |10000010>
# + (-0.01419463474303484+0j) * |10000011>
# + (0.03154871240258217+0j) * |10000100>
# + (-0.01419463474303484+0j) * |10000101>
# + (-0.01419463474303484+0j) * |10000110>
# + (0.19159111380577087+0j) * |10010000>
# + (0.1493048369884491+0j) * |10010010>
# + (0.1493048369884491+0j) * |10010100>
# + (-0.00784763041883707+0j) * |10010101>
# + (-0.01569526083767414+0j) * |10010110>
# + (-0.005231753922998905+0j) * |10011001>
# + (-0.00784763041883707+0j) * |10011010>
# + (0.5326271653175354+0j) * |10100000>
# + (-0.1493048369884491+0j) * |10100001>
# + (0.00784763041883707+0j) * |10100011>
# + (0.1493048369884491+0j) * |10100100>
# + (-0.00784763041883707+0j) * |10100110>
# + (-0.00784763041883707+0j) * |10101001>
# + (-0.01046350784599781+0j) * |10101010>
# + (-0.00784763041883707+0j) * |10101100>
# + (0.14740023016929626+0j) * |10110000>
# + (0.3410360813140869+0j) * |11000000>
# + (-0.1493048369884491+0j) * |11000001>
# + (-0.1493048369884491+0j) * |11000010>
# + (0.01569526083767414+0j) * |11000011>
# + (0.00784763041883707+0j) * |11000101>
# + (-0.00784763041883707+0j) * |11001010>
# + (-0.005231753922998905+0j) * |11001100>
# + (0.14740023016929626+0j) * |11010000>
# + (0.14740023016929626+0j) * |11100000>
# Energy eigenstate |E21> corresponds to eigenvalue: -2.0
# Representation in the computational basis:
# (-0.023694489151239395+0j) * |00010010>
# + (-0.062044501304626465+0j) * |00010100>
# + (0.010660802945494652+0j) * |00010110>
# + (-0.03835001215338707+0j) * |00011000>
# + (0.010660802945494652+0j) * |00011010>
# + (0.010660802945494652+0j) * |00011100>
# + (0.023694489151239395+0j) * |00100001>
# + (-0.03835001215338707+0j) * |00100100>
# + (-0.010660802945494652+0j) * |00100101>
# + (-0.01465552393347025+0j) * |00101000>
# + (-0.010660802945494652+0j) * |00101001>
# + (0.010660802945494652+0j) * |00101100>
# + (0.2525208592414856+0j) * |00110000>
# + (-0.05852213874459267+0j) * |00110011>
# + (-0.1914030909538269+0j) * |00110100>
# + (-0.08778320997953415+0j) * |00110101>
# + (-0.1914030909538269+0j) * |00111000>
# + (0.08778320997953415+0j) * |00111010>
# + (0.1755664199590683+0j) * |00111100>
# + (0.062044501304626465+0j) * |01000001>
# + (0.03835001215338707+0j) * |01000010>
# + (0.010660802945494652+0j) * |01000011>
# + (0.023694489151239395+0j) * |01001000>
# + (-0.010660802945494652+0j) * |01001001>
# + (-0.010660802945494652+0j) * |01001010>
# + (0.2515937387943268+0j) * |01010000>
# + (0.1914030909538269+0j) * |01010010>
# + (-0.08778320997953415+0j) * |01010011>
# + (-0.11704427748918533+0j) * |01010101>
# + (-0.08778320997953415+0j) * |01010110>
# + (-0.1914030909538269+0j) * |01011000>
# + (-0.08778320997953415+0j) * |01011001>
# + (0.08778320997953415+0j) * |01011100>
# + (-0.0009271248709410429+0j) * |01100000>
# + (-0.1914030909538269+0j) * |01100001>
# + (-0.08778320997953415+0j) * |01100101>
# + (-0.05852213874459267+0j) * |01100110>
# + (-0.1914030909538269+0j) * |01101000>
# + (-0.1755664199590683+0j) * |01101001>
# + (-0.08778320997953415+0j) * |01101010>
# + (0.03835001215338707+0j) * |10000001>
# + (0.01465552393347025+0j) * |10000010>
# + (0.010660802945494652+0j) * |10000011>
# + (-0.023694489151239395+0j) * |10000100>
# + (0.010660802945494652+0j) * |10000101>
# + (0.010660802945494652+0j) * |10000110>
# + (-0.0009271248709410429+0j) * |10010000>
# + (0.1914030909538269+0j) * |10010010>
# + (0.1914030909538269+0j) * |10010100>
# + (-0.08778320997953415+0j) * |10010101>
# + (-0.1755664199590683+0j) * |10010110>
# + (-0.05852213874459267+0j) * |10011001>
# + (-0.08778320997953415+0j) * |10011010>
# + (-0.2534479796886444+0j) * |10100000>
# + (-0.1914030909538269+0j) * |10100001>
# + (0.08778320997953415+0j) * |10100011>
# + (0.1914030909538269+0j) * |10100100>
# + (-0.08778320997953415+0j) * |10100110>
# + (-0.08778320997953415+0j) * |10101001>
# + (-0.11704427748918533+0j) * |10101010>
# + (-0.08778320997953415+0j) * |10101100>
# + (-0.2525208592414856+0j) * |11000000>
# + (-0.1914030909538269+0j) * |11000001>
# + (-0.1914030909538269+0j) * |11000010>
# + (0.1755664199590683+0j) * |11000011>
# + (0.08778320997953415+0j) * |11000101>
# + (-0.08778320997953415+0j) * |11001010>
# + (-0.05852213874459267+0j) * |11001100>
# Energy eigenstate |E22> corresponds to eigenvalue: -1.6457513570785522
# Representation in the computational basis:
# (0.10163936764001846+0j) * |00110001>
# + (-0.137459859251976+0j) * |00110010>
# + (-0.2683391273021698+0j) * |00110100>
# + (0.1019260510802269+0j) * |00111000>
# + (0.03582048788666725+0j) * |01010001>
# + (-0.3702651858329773+0j) * |01010010>
# + (-0.03582048788666725+0j) * |01010100>
# + (0.3702651858329773+0j) * |01011000>
# + (-0.1019260510802269+0j) * |01100001>
# + (-0.10163936764001846+0j) * |01100010>
# + (0.137459859251976+0j) * |01100100>
# + (0.2683391273021698+0j) * |01101000>
# + (-0.137459859251976+0j) * |10010001>
# + (-0.2683391273021698+0j) * |10010010>
# + (0.1019260510802269+0j) * |10010100>
# + (0.10163936764001846+0j) * |10011000>
# + (-0.3702651858329773+0j) * |10100001>
# + (-0.03582048788666725+0j) * |10100010>
# + (0.3702651858329773+0j) * |10100100>
# + (0.03582048788666725+0j) * |10101000>
# + (-0.2683391273021698+0j) * |11000001>
# + (0.1019260510802269+0j) * |11000010>
# + (0.10163936764001846+0j) * |11000100>
# + (-0.137459859251976+0j) * |11001000>
# Energy eigenstate |E23> corresponds to eigenvalue: -1.6457513570785522
# Representation in the computational basis:
# (-0.10004345327615738+0j) * |00110001>
# + (-0.038000546395778656+0j) * |00110010>
# + (-0.27261972427368164+0j) * |00110100>
# + (-0.368698388338089+0j) * |00111000>
# + (0.13804399967193604+0j) * |01010001>
# + (0.09607864171266556+0j) * |01010010>
# + (-0.13804399967193604+0j) * |01010100>
# + (-0.09607864171266556+0j) * |01011000>
# + (0.368698388338089+0j) * |01100001>
# + (0.10004345327615738+0j) * |01100010>
# + (0.038000546395778656+0j) * |01100100>
# + (0.27261972427368164+0j) * |01101000>
# + (-0.038000546395778656+0j) * |10010001>
# + (-0.27261972427368164+0j) * |10010010>
# + (-0.368698388338089+0j) * |10010100>
# + (-0.10004345327615738+0j) * |10011000>
# + (0.09607864171266556+0j) * |10100001>
# + (-0.13804399967193604+0j) * |10100010>
# + (-0.09607864171266556+0j) * |10100100>
# + (0.13804399967193604+0j) * |10101000>
# + (-0.27261972427368164+0j) * |11000001>
# + (-0.368698388338089+0j) * |11000010>
# + (-0.10004345327615738+0j) * |11000100>
# + (-0.038000546395778656+0j) * |11001000>
# Energy eigenstate |E24> corresponds to eigenvalue: -1.6457513570785522
# Representation in the computational basis:
# (0.0923689603805542+0j) * |00010011>
# + (0.04791877418756485+0j) * |00010101>
# + (-0.0688348338007927+0j) * |00010110>
# + (-0.14028772711753845+0j) * |00011001>
# + (-0.3602883815765381+0j) * |00011010>
# + (-0.2914535403251648+0j) * |00011100>
# + (-0.14028772711753845+0j) * |00100011>
# + (-0.3602883815765381+0j) * |00100101>
# + (-0.0923689603805542+0j) * |00100110>
# + (-0.2914535403251648+0j) * |00101001>
# + (-0.04791877418756485+0j) * |00101010>
# + (0.0688348338007927+0j) * |00101100>
# + (-0.2914535403251648+0j) * |01000011>
# + (-0.04791877418756485+0j) * |01000101>
# + (0.14028772711753845+0j) * |01000110>
# + (0.0688348338007927+0j) * |01001001>
# + (0.3602883815765381+0j) * |01001010>
# + (0.0923689603805542+0j) * |01001100>
# + (0.0688348338007927+0j) * |10000011>
# + (0.3602883815765381+0j) * |10000101>
# + (0.2914535403251648+0j) * |10000110>
# + (0.0923689603805542+0j) * |10001001>
# + (0.04791877418756485+0j) * |10001010>
# + (-0.14028772711753845+0j) * |10001100>
# Energy eigenstate |E25> corresponds to eigenvalue: -1.6457513570785522
# Representation in the computational basis:
# (-0.10866107791662216+0j) * |00010011>
# + (0.13432440161705017+0j) * |00010101>
# + (0.3762833774089813+0j) * |00010110>
# + (-0.025663325563073158+0j) * |00011001>
# + (0.12852896749973297+0j) * |00011010>
# + (-0.24775439500808716+0j) * |00011100>
# + (-0.025663325563073158+0j) * |00100011>
# + (0.12852896749973297+0j) * |00100101>
# + (0.10866107791662216+0j) * |00100110>
# + (-0.24775439500808716+0j) * |00101001>
# + (-0.13432440161705017+0j) * |00101010>
# + (-0.3762833774089813+0j) * |00101100>
# + (-0.24775439500808716+0j) * |01000011>
# + (-0.13432440161705017+0j) * |01000101>
# + (0.025663325563073158+0j) * |01000110>
# + (-0.3762833774089813+0j) * |01001001>
# + (-0.12852896749973297+0j) * |01001010>
# + (-0.10866107791662216+0j) * |01001100>
# + (-0.3762833774089813+0j) * |10000011>
# + (-0.12852896749973297+0j) * |10000101>
# + (0.24775439500808716+0j) * |10000110>
# + (-0.10866107791662216+0j) * |10001001>
# + (0.13432440161705017+0j) * |10001010>
# + (-0.025663325563073158+0j) * |10001100>
# Energy eigenstate |E26> corresponds to eigenvalue: -1.6272130012512207
# Representation in the computational basis:
# (-0.1832745522260666+0j) * |00110101>
# + (-0.20211060345172882+0j) * |00110110>
# + (-0.20211060345172882+0j) * |00111001>
# + (-0.1832745522260666+0j) * |00111010>
# + (-0.1832745522260666+0j) * |01010011>
# + (-0.26055464148521423+0j) * |01010101>
# + (-0.1832745522260666+0j) * |01010110>
# + (-0.1832745522260666+0j) * |01011001>
# + (0.1832745522260666+0j) * |01011100>
# + (-0.20211060345172882+0j) * |01100011>
# + (-0.1832745522260666+0j) * |01100101>
# + (0.1832745522260666+0j) * |01101010>
# + (0.20211060345172882+0j) * |01101100>
# + (-0.20211060345172882+0j) * |10010011>
# + (-0.1832745522260666+0j) * |10010101>
# + (0.1832745522260666+0j) * |10011010>
# + (0.20211060345172882+0j) * |10011100>
# + (-0.1832745522260666+0j) * |10100011>
# + (0.1832745522260666+0j) * |10100110>
# + (0.1832745522260666+0j) * |10101001>
# + (0.26055464148521423+0j) * |10101010>
# + (0.1832745522260666+0j) * |10101100>
# + (0.1832745522260666+0j) * |11000101>
# + (0.20211060345172882+0j) * |11000110>
# + (0.20211060345172882+0j) * |11001001>
# + (0.1832745522260666+0j) * |11001010>
# Energy eigenstate |E27> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (-0.01693516969680786+0j) * |00010010>
# + (0.15505968034267426+0j) * |00010111>
# + (0.01693516969680786+0j) * |00011000>
# + (-0.2110089659690857+0j) * |00011101>
# + (-0.09052783995866776+0j) * |00011110>
# + (-0.01693516969680786+0j) * |00100001>
# + (-0.02093302272260189+0j) * |00100010>
# + (-0.01693516969680786+0j) * |00100100>
# + (-0.15505968034267426+0j) * |00101011>
# + (-0.5923115015029907+0j) * |00101101>
# + (-0.2110089659690857+0j) * |00101110>
# + (0.01209452748298645+0j) * |00110101>
# + (-0.01209452748298645+0j) * |00111010>
# + (-0.03913871571421623+0j) * |00111100>
# + (-0.01693516969680786+0j) * |01000010>
# + (0.2110089659690857+0j) * |01000111>
# + (0.01693516969680786+0j) * |01001000>
# + (0.09052783995866776+0j) * |01001011>
# + (-0.15505968034267426+0j) * |01001101>
# + (-0.01209452748298645+0j) * |01010011>
# + (-0.0030297692865133286+0j) * |01010110>
# + (0.0030297692865133286+0j) * |01011001>
# + (-0.01209452748298645+0j) * |01011100>
# + (0.0030297692865133286+0j) * |01100101>
# + (0.009804539382457733+0j) * |01101001>
# + (0.0030297692865133286+0j) * |01101010>
# + (0.01693516969680786+0j) * |10000001>
# + (0.01693516969680786+0j) * |10000100>
# + (0.5923115015029907+0j) * |10000111>
# + (0.02093302272260189+0j) * |10001000>
# + (0.2110089659690857+0j) * |10001011>
# + (0.15505968034267426+0j) * |10001110>
# + (-0.0030297692865133286+0j) * |10010101>
# + (-0.009804539382457733+0j) * |10010110>
# + (-0.0030297692865133286+0j) * |10011010>
# + (0.01209452748298645+0j) * |10100011>
# + (-0.0030297692865133286+0j) * |10100110>
# + (0.0030297692865133286+0j) * |10101001>
# + (0.01209452748298645+0j) * |10101100>
# + (0.03913871571421623+0j) * |11000011>
# + (0.01209452748298645+0j) * |11000101>
# + (-0.01209452748298645+0j) * |11001010>
# Energy eigenstate |E28> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (0.00014905356511007994+0j) * |00010010>
# + (-0.0013647456653416157+0j) * |00010111>
# + (-0.00014905356511007994+0j) * |00011000>
# + (-0.0010158155346289277+0j) * |00011101>
# + (-0.0038518288638442755+0j) * |00011110>
# + (0.00014905356511007994+0j) * |00100001>
# + (0.00018424034351482987+0j) * |00100010>
# + (0.00014905356511007994+0j) * |00100100>
# + (0.0013647456653416157+0j) * |00101011>
# + (0.0005645807250402868+0j) * |00101101>
# + (-0.0010158155346289277+0j) * |00101110>
# + (0.04397040978074074+0j) * |00110101>
# + (-0.04397040978074074+0j) * |00111010>
# + (-0.14229123294353485+0j) * |00111100>
# + (0.00014905356511007994+0j) * |01000010>
# + (0.0010158155346289277+0j) * |01000111>
# + (-0.00014905356511007994+0j) * |01001000>
# + (0.0038518288638442755+0j) * |01001011>
# + (0.0013647456653416157+0j) * |01001101>
# + (-0.04397040978074074+0j) * |01010011>
# + (0.17565752565860748+0j) * |01010110>
# + (-0.17565752565860748+0j) * |01011001>
# + (-0.04397040978074074+0j) * |01011100>
# + (-0.17565752565860748+0j) * |01100101>
# + (-0.5684396624565125+0j) * |01101001>
# + (-0.17565752565860748+0j) * |01101010>
# + (-0.059172794222831726+0j) * |01110001>
# + (0.004005481954663992+0j) * |01110100>
# + (-0.08926258236169815+0j) * |01111000>
# + (-0.00014905356511007994+0j) * |10000001>
# + (-0.00014905356511007994+0j) * |10000100>
# + (-0.0005645807250402868+0j) * |10000111>
# + (-0.00018424034351482987+0j) * |10001000>
# + (0.0010158155346289277+0j) * |10001011>
# + (-0.0013647456653416157+0j) * |10001110>
# + (0.17565752565860748+0j) * |10010101>
# + (0.5684396624565125+0j) * |10010110>
# + (0.17565752565860748+0j) * |10011010>
# + (0.04397040978074074+0j) * |10100011>
# + (0.17565752565860748+0j) * |10100110>
# + (-0.17565752565860748+0j) * |10101001>
# + (0.04397040978074074+0j) * |10101100>
# + (0.059172794222831726+0j) * |10110010>
# + (0.10222459584474564+0j) * |10110100>
# + (0.004005481954663992+0j) * |10111000>
# + (0.14229123294353485+0j) * |11000011>
# + (0.04397040978074074+0j) * |11000101>
# + (-0.04397040978074074+0j) * |11001010>
# + (-0.004005481954663992+0j) * |11010001>
# + (0.08926258236169815+0j) * |11010010>
# + (0.059172794222831726+0j) * |11010100>
# + (-0.10222459584474564+0j) * |11100001>
# + (-0.004005481954663992+0j) * |11100010>
# + (-0.059172794222831726+0j) * |11101000>
# Energy eigenstate |E29> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (0.01763187348842621+0j) * |01110001>
# + (0.26227355003356934+0j) * |01110100>
# + (0.45289650559425354+0j) * |01111000>
# + (-0.01763187348842621+0j) * |10110010>
# + (0.39583855867385864+0j) * |10110100>
# + (0.26227355003356934+0j) * |10111000>
# + (-0.26227355003356934+0j) * |11010001>
# + (-0.45289650559425354+0j) * |11010010>
# + (-0.01763187348842621+0j) * |11010100>
# + (-0.39583855867385864+0j) * |11100001>
# + (-0.26227355003356934+0j) * |11100010>
# + (0.01763187348842621+0j) * |11101000>
# Energy eigenstate |E30> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (-0.29938948154449463+0j) * |00010010>
# + (-0.024979395791888237+0j) * |00010111>
# + (0.29938948154449463+0j) * |00011000>
# + (-0.04041751101613045+0j) * |00011110>
# + (-0.29938948154449463+0j) * |00100001>
# + (-0.37006574869155884+0j) * |00100010>
# + (-0.29938948154449463+0j) * |00100100>
# + (0.024979395791888237+0j) * |00101011>
# + (0.04041751101613045+0j) * |00101101>
# + (-0.29938948154449463+0j) * |01000010>
# + (0.29938948154449463+0j) * |01001000>
# + (0.04041751101613045+0j) * |01001011>
# + (0.024979395791888237+0j) * |01001101>
# + (0.29938948154449463+0j) * |10000001>
# + (0.29938948154449463+0j) * |10000100>
# + (-0.04041751101613045+0j) * |10000111>
# + (0.37006574869155884+0j) * |10001000>
# + (-0.024979395791888237+0j) * |10001110>
# Energy eigenstate |E31> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (-0.0003160661435686052+0j) * |00010111>
# + (-0.00023525621509179473+0j) * |00011101>
# + (-0.0008920583059079945+0j) * |00011110>
# + (0.0003160661435686052+0j) * |00101011>
# + (0.00013075319293420762+0j) * |00101101>
# + (-0.00023525621509179473+0j) * |00101110>
# + (0.010183258913457394+0j) * |00110101>
# + (-0.010183258913457394+0j) * |00111010>
# + (-0.032953716814517975+0j) * |00111100>
# + (0.00023525621509179473+0j) * |01000111>
# + (0.0008920583059079945+0j) * |01001011>
# + (0.0003160661435686052+0j) * |01001101>
# + (-0.010183258913457394+0j) * |01010011>
# + (0.040681131184101105+0j) * |01010110>
# + (-0.040681131184101105+0j) * |01011001>
# + (-0.010183258913457394+0j) * |01011100>
# + (-0.040681131184101105+0j) * |01100101>
# + (-0.13164690136909485+0j) * |01101001>
# + (-0.040681131184101105+0j) * |01101010>
# + (0.25551125407218933+0j) * |01110001>
# + (-0.017170902341604233+0j) * |01110100>
# + (0.38564276695251465+0j) * |01111000>
# + (-0.00013075319293420762+0j) * |10000111>
# + (0.00023525621509179473+0j) * |10001011>
# + (-0.0003160661435686052+0j) * |10001110>
# + (0.040681131184101105+0j) * |10010101>
# + (0.13164690136909485+0j) * |10010110>
# + (0.040681131184101105+0j) * |10011010>
# + (0.010183258913457394+0j) * |10100011>
# + (0.040681131184101105+0j) * |10100110>
# + (-0.040681131184101105+0j) * |10101001>
# + (0.010183258913457394+0j) * |10101100>
# + (-0.25551125407218933+0j) * |10110010>
# + (-0.44120898842811584+0j) * |10110100>
# + (-0.017170902341604233+0j) * |10111000>
# + (0.032953716814517975+0j) * |11000011>
# + (0.010183258913457394+0j) * |11000101>
# + (-0.010183258913457394+0j) * |11001010>
# + (0.017170902341604233+0j) * |11010001>
# + (-0.38564276695251465+0j) * |11010010>
# + (-0.25551125407218933+0j) * |11010100>
# + (0.44120898842811584+0j) * |11100001>
# + (0.017170902341604233+0j) * |11100010>
# + (0.25551125407218933+0j) * |11101000>
# Energy eigenstate |E32> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (0.37174803018569946+0j) * |00010001>
# + (0.3007504642009735+0j) * |00010010>
# + (0.3007504642009735+0j) * |00011000>
# + (0.3007504642009735+0j) * |00100001>
# + (-0.3007504642009735+0j) * |00100100>
# + (-0.3007504642009735+0j) * |01000010>
# + (-0.37174803018569946+0j) * |01000100>
# + (-0.3007504642009735+0j) * |01001000>
# + (0.3007504642009735+0j) * |10000001>
# + (-0.3007504642009735+0j) * |10000100>
# Energy eigenstate |E33> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (-0.001751328818500042+0j) * |00010010>
# + (0.016035297885537148+0j) * |00010111>
# + (0.001751328818500042+0j) * |00011000>
# + (-0.0100179398432374+0j) * |00011101>
# + (0.009736289270222187+0j) * |00011110>
# + (-0.001751328818500042+0j) * |00100001>
# + (-0.002164761535823345+0j) * |00100010>
# + (-0.001751328818500042+0j) * |00100100>
# + (-0.016035297885537148+0j) * |00101011>
# + (-0.04215502366423607+0j) * |00101101>
# + (-0.0100179398432374+0j) * |00101110>
# + (-0.17983265221118927+0j) * |00110101>
# + (0.17983265221118927+0j) * |00111010>
# + (0.5819507241249084+0j) * |00111100>
# + (-0.001751328818500042+0j) * |01000010>
# + (0.0100179398432374+0j) * |01000111>
# + (0.001751328818500042+0j) * |01001000>
# + (-0.009736289270222187+0j) * |01001011>
# + (-0.016035297885537148+0j) * |01001101>
# + (0.17983265221118927+0j) * |01010011>
# + (0.04504941776394844+0j) * |01010110>
# + (-0.04504941776394844+0j) * |01011001>
# + (0.17983265221118927+0j) * |01011100>
# + (-0.04504941776394844+0j) * |01100101>
# + (-0.1457829773426056+0j) * |01101001>
# + (-0.04504941776394844+0j) * |01101010>
# + (0.001751328818500042+0j) * |10000001>
# + (0.001751328818500042+0j) * |10000100>
# + (0.04215502366423607+0j) * |10000111>
# + (0.002164761535823345+0j) * |10001000>
# + (0.0100179398432374+0j) * |10001011>
# + (0.016035297885537148+0j) * |10001110>
# + (0.04504941776394844+0j) * |10010101>
# + (0.1457829773426056+0j) * |10010110>
# + (0.04504941776394844+0j) * |10011010>
# + (-0.17983265221118927+0j) * |10100011>
# + (0.04504941776394844+0j) * |10100110>
# + (-0.04504941776394844+0j) * |10101001>
# + (-0.17983265221118927+0j) * |10101100>
# + (-0.5819507241249084+0j) * |11000011>
# + (-0.17983265221118927+0j) * |11000101>
# + (0.17983265221118927+0j) * |11001010>
# Energy eigenstate |E34> corresponds to eigenvalue: -1.2360680103302002
# Representation in the computational basis:
# (0.022954238578677177+0j) * |00010010>
# + (-0.210170716047287+0j) * |00010111>
# + (-0.022954238578677177+0j) * |00011000>
# + (-0.1564355194568634+0j) * |00011101>
# + (-0.5931813716888428+0j) * |00011110>
# + (0.022954238578677177+0j) * |00100001>
# + (0.028372999280691147+0j) * |00100010>
# + (0.022954238578677177+0j) * |00100100>
# + (0.210170716047287+0j) * |00101011>
# + (0.08694539219141006+0j) * |00101101>
# + (-0.1564355194568634+0j) * |00101110>
# + (-0.005098348017781973+0j) * |00110101>
# + (0.005098348017781973+0j) * |00111010>
# + (0.01649860106408596+0j) * |00111100>
# + (0.022954238578677177+0j) * |01000010>
# + (0.1564355194568634+0j) * |01000111>
# + (-0.022954238578677177+0j) * |01001000>
# + (0.5931813716888428+0j) * |01001011>
# + (0.210170716047287+0j) * |01001101>
# + (0.005098348017781973+0j) * |01010011>
# + (0.005098348017781973+0j) * |01011100>
# + (-0.022954238578677177+0j) * |10000001>
# + (-0.022954238578677177+0j) * |10000100>
# + (-0.08694539219141006+0j) * |10000111>
# + (-0.028372999280691147+0j) * |10001000>
# + (0.1564355194568634+0j) * |10001011>
# + (-0.210170716047287+0j) * |10001110>
# + (-0.005098348017781973+0j) * |10100011>
# + (-0.005098348017781973+0j) * |10101100>
# + (-0.01649860106408596+0j) * |11000011>
# + (-0.005098348017781973+0j) * |11000101>
# + (0.005098348017781973+0j) * |11001010>
# Energy eigenstate |E35> corresponds to eigenvalue: -1.2092515230178833
# Representation in the computational basis:
# (-0.18797314167022705+0j) * |00110111>
# + (-0.18664227426052094+0j) * |00111011>
# + (-0.3051176965236664+0j) * |00111101>
# + (-0.3029574155807495+0j) * |00111110>
# + (-0.18664227426052094+0j) * |01010111>
# + (-0.26887398958206177+0j) * |01011011>
# + (-0.18664227426052094+0j) * |01011101>
# + (-0.26887398958206177+0j) * |01011110>
# + (0.0223285723477602+0j) * |01100111>
# + (0.03624369949102402+0j) * |01101101>
# + (0.03624369949102402+0j) * |10010111>
# + (0.0223285723477602+0j) * |10011101>
# + (0.3029574155807495+0j) * |10100111>
# + (0.2103017270565033+0j) * |10101011>
# + (0.3029574155807495+0j) * |10101101>
# + (0.2103017270565033+0j) * |10101110>
# + (0.3051176965236664+0j) * |11000111>
# + (0.3029574155807495+0j) * |11001011>
# + (0.18797314167022705+0j) * |11001101>
# + (0.18664227426052094+0j) * |11001110>
# Energy eigenstate |E36> corresponds to eigenvalue: -1.2092515230178833
# Representation in the computational basis:
# (-0.013936753384768963+0j) * |01110011>
# + (-0.22356098890304565+0j) * |01110101>
# + (-0.18447308242321014+0j) * |01110110>
# + (-0.29943639039993286+0j) * |01111001>
# + (-0.24567201733589172+0j) * |01111010>
# ...
# + (-0.0025680316612124443+0j) * |10111101>
# + (0.007122216280549765+0j) * |10111110>
# + (-0.7026493549346924+0j) * |10111111>
# + (-0.0010913932928815484+0j) * |11001101>
# + (0.0010913932928815484+0j) * |11001110>
# + (-0.0009755634237080812+0j) * |11001111>
# + (0.0013983432436361909+0j) * |11010101>
# + (0.0019861531909555197+0j) * |11010111>
# + (-0.0013983432436361909+0j) * |11011001>
# + (0.0025680316612124443+0j) * |11011011>
# + (0.0013983432436361909+0j) * |11011100>
# + (0.055196478962898254+0j) * |11011101>
# + (-0.00455418461933732+0j) * |11011110>
# + (0.006945546250790358+0j) * |11011111>
# + (-0.0013983432436361909+0j) * |11100110>
# + (0.0025680316612124443+0j) * |11100111>
# + (0.0013983432436361909+0j) * |11101010>
# + (-0.007122216280549765+0j) * |11101011>
# + (-0.0013983432436361909+0j) * |11101100>
# + (0.00455418461933732+0j) * |11101101>
# + (-0.055196478962898254+0j) * |11101110>
# + (0.7026493549346924+0j) * |11101111>
# Energy eigenstate |E242> corresponds to eigenvalue: 6.0
# Representation in the computational basis:
# (-0.0010860975598916411+0j) * |00110011>
# + (0.0005430487799458206+0j) * |00110101>
# + (0.11705770343542099+0j) * |00110111>
# + (-0.0005430487799458206+0j) * |00111010>
# + (-0.11705770343542099+0j) * |00111011>
# + (0.0003620325296651572+0j) * |00111100>
# + (-0.10463432967662811+0j) * |00111111>
# + (0.0005430487799458206+0j) * |01010011>
# + (-0.0005430487799458206+0j) * |01010110>
# + (-0.11705770343542099+0j) * |01010111>
# + (-0.0005430487799458206+0j) * |01011001>
# + (0.0007240650593303144+0j) * |01011010>
# + (-0.0005430487799458206+0j) * |01011100>
# + (0.11705770343542099+0j) * |01011101>
# + (-0.16029958426952362+0j) * |01011111>
# + (-0.0005430487799458206+0j) * |01100101>
# + (0.0010860975598916411+0j) * |01100110>
# + (0.11705770343542099+0j) * |01100111>
# + (0.0003620325296651572+0j) * |01101001>
# + (-0.0005430487799458206+0j) * |01101010>
# + (-0.11705770343542099+0j) * |01101110>
# + (0.26493391394615173+0j) * |01101111>
# + (-0.14997979998588562+0j) * |01110011>
# + (0.14997979998588562+0j) * |01110101>
# + (-0.14997979998588562+0j) * |01110110>
# + (0.060439981520175934+0j) * |01110111>
# + (0.06909018754959106+0j) * |01111011>
# + (-0.11771000176668167+0j) * |01111101>
# + (0.04861981049180031+0j) * |01111110>
# + (-0.2908831238746643+0j) * |01111111>
# + (-0.0005430487799458206+0j) * |10010101>
# + (0.0003620325296651572+0j) * |10010110>
# + (0.0010860975598916411+0j) * |10011001>
# + (-0.0005430487799458206+0j) * |10011010>
# + (0.11705770343542099+0j) * |10011011>
# + (-0.11705770343542099+0j) * |10011101>
# + (0.26493391394615173+0j) * |10011111>
# + (-0.0005430487799458206+0j) * |10100011>
# + (0.0007240650593303144+0j) * |10100101>
# + (-0.0005430487799458206+0j) * |10100110>
# + (-0.0005430487799458206+0j) * |10101001>
# + (-0.11705770343542099+0j) * |10101011>
# + (0.0005430487799458206+0j) * |10101100>
# + (0.11705770343542099+0j) * |10101110>
# + (-0.36956822872161865+0j) * |10101111>
# + (0.14997979998588562+0j) * |10110011>
# + (-0.06909018754959106+0j) * |10110111>
# + (-0.14997979998588562+0j) * |10111001>
# + (0.14997979998588562+0j) * |10111010>
# + (-0.060439981520175934+0j) * |10111011>
# + (0.04861981049180031+0j) * |10111101>
# + (0.020470375195145607+0j) * |10111110>
# + (0.008416343480348587+0j) * |10111111>
# + (0.0003620325296651572+0j) * |11000011>
# + (-0.0005430487799458206+0j) * |11000101>
# + (0.0005430487799458206+0j) * |11001010>
# + (-0.0010860975598916411+0j) * |11001100>
# + (0.11705770343542099+0j) * |11001101>
# + (-0.11705770343542099+0j) * |11001110>
# + (0.10463432967662811+0j) * |11001111>
# + (-0.14997979998588562+0j) * |11010101>
# + (0.11771000176668167+0j) * |11010111>
# + (0.14997979998588562+0j) * |11011001>
# + (-0.04861981049180031+0j) * |11011011>
# + (-0.14997979998588562+0j) * |11011100>
# + (0.060439981520175934+0j) * |11011101>
# + (-0.06909018754959106+0j) * |11011110>
# + (0.2908831238746643+0j) * |11011111>
# + (0.14997979998588562+0j) * |11100110>
# + (-0.04861981049180031+0j) * |11100111>
# + (-0.14997979998588562+0j) * |11101010>
# + (-0.020470375195145607+0j) * |11101011>
# + (0.14997979998588562+0j) * |11101100>
# + (0.06909018754959106+0j) * |11101101>
# + (-0.060439981520175934+0j) * |11101110>
# + (-0.008416343480348587+0j) * |11101111>
# Energy eigenstate |E243> corresponds to eigenvalue: 6.0
# Representation in the computational basis:
# (-0.00033224598155356944+0j) * |00110011>
# + (0.00016612299077678472+0j) * |00110101>
# + (0.03580889105796814+0j) * |00110111>
# + (-0.00016612299077678472+0j) * |00111010>
# + (-0.03580889105796814+0j) * |00111011>
# + (0.00011074866051785648+0j) * |00111100>
# + (-0.03200848400592804+0j) * |00111111>
# + (0.00016612299077678472+0j) * |01010011>
# + (-0.00016612299077678472+0j) * |01010110>
# + (-0.03580889105796814+0j) * |01010111>
# + (-0.00016612299077678472+0j) * |01011001>
# + (0.00022149732103571296+0j) * |01011010>
# + (-0.00016612299077678472+0j) * |01011100>
# + (0.03580889105796814+0j) * |01011101>
# + (-0.04903692752122879+0j) * |01011111>
# + (-0.00016612299077678472+0j) * |01100101>
# + (0.00033224598155356944+0j) * |01100110>
# + (0.03580889105796814+0j) * |01100111>
# + (0.00011074866051785648+0j) * |01101001>
# + (-0.00016612299077678472+0j) * |01101010>
# + (-0.03580889105796814+0j) * |01101110>
# + (0.08104541152715683+0j) * |01101111>
# + (-0.0458800233900547+0j) * |01110011>
# + (0.0458800233900547+0j) * |01110101>
# + (-0.0458800233900547+0j) * |01110110>
# + (-0.023683931678533554+0j) * |01110111>
# + (-0.31381621956825256+0j) * |01111011>
# + (0.44544652104377747+0j) * |01111101>
# + (-0.1316303014755249+0j) * |01111110>
# + (0.002731571439653635+0j) * |01111111>
# + (-0.00016612299077678472+0j) * |10010101>
# + (0.00011074866051785648+0j) * |10010110>
# + (0.00033224598155356944+0j) * |10011001>
# + (-0.00016612299077678472+0j) * |10011010>
# + (0.03580889105796814+0j) * |10011011>
# + (-0.03580889105796814+0j) * |10011101>
# + (0.08104541152715683+0j) * |10011111>
# + (-0.00016612299077678472+0j) * |10100011>
# + (0.00022149732103571296+0j) * |10100101>
# + (-0.00016612299077678472+0j) * |10100110>
# + (-0.00016612299077678472+0j) * |10101001>
# + (-0.03580889105796814+0j) * |10101011>
# + (0.00016612299077678472+0j) * |10101100>
# + (0.03580889105796814+0j) * |10101110>
# + (-0.11305389553308487+0j) * |10101111>
# + (0.0458800233900547+0j) * |10110011>
# + (0.31381621956825256+0j) * |10110111>
# + (-0.0458800233900547+0j) * |10111001>
# + (0.0458800233900547+0j) * |10111010>
# + (0.023683931678533554+0j) * |10111011>
# + (-0.1316303014755249+0j) * |10111101>
# + (-0.18218590319156647+0j) * |10111110>
# + (-0.011499867774546146+0j) * |10111111>
# + (0.00011074866051785648+0j) * |11000011>
# + (-0.00016612299077678472+0j) * |11000101>
# + (0.00016612299077678472+0j) * |11001010>
# + (-0.00033224598155356944+0j) * |11001100>
# + (0.03580889105796814+0j) * |11001101>
# + (-0.03580889105796814+0j) * |11001110>
# + (0.03200848400592804+0j) * |11001111>
# + (-0.0458800233900547+0j) * |11010101>
# + (-0.44544652104377747+0j) * |11010111>
# + (0.0458800233900547+0j) * |11011001>
# + (0.1316303014755249+0j) * |11011011>
# + (-0.0458800233900547+0j) * |11011100>
# + (-0.023683931678533554+0j) * |11011101>
# + (0.31381621956825256+0j) * |11011110>
# + (-0.002731571439653635+0j) * |11011111>
# + (0.0458800233900547+0j) * |11100110>
# + (0.1316303014755249+0j) * |11100111>
# + (-0.0458800233900547+0j) * |11101010>
# + (0.18218590319156647+0j) * |11101011>
# + (0.0458800233900547+0j) * |11101100>
# + (-0.31381621956825256+0j) * |11101101>
# + (0.023683931678533554+0j) * |11101110>
# + (0.011499867774546146+0j) * |11101111>
# Energy eigenstate |E244> corresponds to eigenvalue: 6.685846328735352
# Representation in the computational basis:
# (0.1589638739824295+0j) * |00110101>
# + (-0.13569705188274384+0j) * |00110110>
# + (-0.13569705188274384+0j) * |00111001>
# + (0.1589638739824295+0j) * |00111010>
# + (0.1589638739824295+0j) * |01010011>
# + (-0.47348615527153015+0j) * |01010101>
# + (0.1589638739824295+0j) * |01010110>
# + (0.1589638739824295+0j) * |01011001>
# + (-0.1589638739824295+0j) * |01011100>
# + (-0.13569705188274384+0j) * |01100011>
# + (0.1589638739824295+0j) * |01100101>
# + (-0.1589638739824295+0j) * |01101010>
# + (0.13569705188274384+0j) * |01101100>
# + (-0.13569705188274384+0j) * |10010011>
# + (0.1589638739824295+0j) * |10010101>
# + (-0.1589638739824295+0j) * |10011010>
# + (0.13569705188274384+0j) * |10011100>
# + (0.1589638739824295+0j) * |10100011>
# + (-0.1589638739824295+0j) * |10100110>
# + (-0.1589638739824295+0j) * |10101001>
# + (0.47348615527153015+0j) * |10101010>
# + (-0.1589638739824295+0j) * |10101100>
# + (-0.1589638739824295+0j) * |11000101>
# + (0.13569705188274384+0j) * |11000110>
# + (0.13569705188274384+0j) * |11001001>
# + (-0.1589638739824295+0j) * |11001010>
# Energy eigenstate |E245> corresponds to eigenvalue: 6.828427314758301
# Representation in the computational basis:
# (0.2198663055896759+0j) * |00110011>
# + (-0.15546895563602448+0j) * |00110101>
# + (0.15546895563602448+0j) * |00111010>
# + (-0.09107160568237305+0j) * |00111100>
# + (-0.15546895563602448+0j) * |01010011>
# + (0.4397326111793518+0j) * |01010101>
# + (-0.15546895563602448+0j) * |01010110>
# + (-0.15546895563602448+0j) * |01011001>
# + (0.15546895563602448+0j) * |01011100>
# + (-0.15546895563602448+0j) * |01100101>
# + (0.2198663055896759+0j) * |01100110>
# + (0.09107160568237305+0j) * |01101001>
# + (-0.15546895563602448+0j) * |01101010>
# + (-0.15546895563602448+0j) * |10010101>
# + (0.09107160568237305+0j) * |10010110>
# + (0.2198663055896759+0j) * |10011001>
# + (-0.15546895563602448+0j) * |10011010>
# + (0.15546895563602448+0j) * |10100011>
# + (-0.15546895563602448+0j) * |10100110>
# + (-0.15546895563602448+0j) * |10101001>
# + (0.4397326111793518+0j) * |10101010>
# + (-0.15546895563602448+0j) * |10101100>
# + (-0.09107160568237305+0j) * |11000011>
# + (0.15546895563602448+0j) * |11000101>
# + (-0.15546895563602448+0j) * |11001010>
# + (0.2198663055896759+0j) * |11001100>
# Energy eigenstate |E246> corresponds to eigenvalue: 7.209251403808594
# Representation in the computational basis:
# (0.3046860992908478+0j) * |01110011>
# + (-0.2882329821586609+0j) * |01110101>
# + (0.0200843196362257+0j) * |01110110>
# + (0.012373300269246101+0j) * |01111001>
# + (0.1975599229335785+0j) * |01111010>
# + (-0.18770726025104523+0j) * |01111100>
# + (-0.30445596575737+0j) * |10110011>
# + (0.20008055865764618+0j) * |10110101>
# + (0.009994450025260448+0j) * |10110110>
# + (0.01622297428548336+0j) * |10111001>
# + (-0.28460177779197693+0j) * |10111010>
# + (0.18756547570228577+0j) * |10111100>
# + (0.18770726025104523+0j) * |11010011>
# + (-0.2882329821586609+0j) * |11010101>
# + (0.012373300269246101+0j) * |11010110>
# + (0.0200843196362257+0j) * |11011001>
# + (0.1975599229335785+0j) * |11011010>
# + (-0.3046860992908478+0j) * |11011100>
# + (-0.18756547570228577+0j) * |11100011>
# + (0.20008055865764618+0j) * |11100101>
# + (0.01622297428548336+0j) * |11100110>
# + (0.009994450025260448+0j) * |11101001>
# + (-0.28460177779197693+0j) * |11101010>
# + (0.30445596575737+0j) * |11101100>
# Energy eigenstate |E247> corresponds to eigenvalue: 7.209251403808594
# Representation in the computational basis:
# (0.01622297428548336+0j) * |01110011>
# + (-0.28460177779197693+0j) * |01110101>
# + (0.30445596575737+0j) * |01110110>
# + (0.18756547570228577+0j) * |01111001>
# + (-0.20008055865764618+0j) * |01111010>
# + (-0.009994450025260448+0j) * |01111100>
# + (0.0200843196362257+0j) * |10110011>
# + (0.1975599229335785+0j) * |10110101>
# + (-0.18770726025104523+0j) * |10110110>
# + (-0.3046860992908478+0j) * |10111001>
# + (0.2882329821586609+0j) * |10111010>
# + (-0.012373300269246101+0j) * |10111100>
# + (0.009994450025260448+0j) * |11010011>
# + (-0.28460177779197693+0j) * |11010101>
# + (0.18756547570228577+0j) * |11010110>
# + (0.30445596575737+0j) * |11011001>
# + (-0.20008055865764618+0j) * |11011010>
# + (-0.01622297428548336+0j) * |11011100>
# + (0.012373300269246101+0j) * |11100011>
# + (0.1975599229335785+0j) * |11100101>
# + (-0.3046860992908478+0j) * |11100110>
# + (-0.18770726025104523+0j) * |11101001>
# + (0.2882329821586609+0j) * |11101010>
# + (-0.0200843196362257+0j) * |11101100>
# Energy eigenstate |E248> corresponds to eigenvalue: 7.209251403808594
# Representation in the computational basis:
# (-0.3051176965236664+0j) * |00110111>
# + (0.3029574155807495+0j) * |00111011>
# + (-0.18797314167022705+0j) * |00111101>
# + (0.18664227426052094+0j) * |00111110>
# + (0.3029574155807495+0j) * |01010111>
# + (-0.2103017270565033+0j) * |01011011>
# + (0.3029574155807495+0j) * |01011101>
# + (-0.2103017270565033+0j) * |01011110>
# + (-0.03624369949102402+0j) * |01100111>
# + (-0.0223285723477602+0j) * |01101101>
# + (-0.0223285723477602+0j) * |10010111>
# + (-0.03624369949102402+0j) * |10011101>
# + (-0.18664227426052094+0j) * |10100111>
# + (0.26887398958206177+0j) * |10101011>
# + (-0.18664227426052094+0j) * |10101101>
# + (0.26887398958206177+0j) * |10101110>
# + (0.18797314167022705+0j) * |11000111>
# + (-0.18664227426052094+0j) * |11001011>
# + (0.3051176965236664+0j) * |11001101>
# + (-0.3029574155807495+0j) * |11001110>
# Energy eigenstate |E249> corresponds to eigenvalue: 7.209251403808594
# Representation in the computational basis:
# (-0.03624369949102402+0j) * |00111011>
# + (-0.0223285723477602+0j) * |00111110>
# + (0.26887398958206177+0j) * |01010111>
# + (-0.18664227426052094+0j) * |01011011>
# + (0.26887398958206177+0j) * |01011101>
# + (-0.18664227426052094+0j) * |01011110>
# + (-0.3029574155807495+0j) * |01100111>
# + (0.18797314167022705+0j) * |01101011>
# + (-0.18664227426052094+0j) * |01101101>
# + (0.3051176965236664+0j) * |01101110>
# + (-0.18664227426052094+0j) * |10010111>
# + (0.3051176965236664+0j) * |10011011>
# + (-0.3029574155807495+0j) * |10011101>
# + (0.18797314167022705+0j) * |10011110>
# + (0.2103017270565033+0j) * |10100111>
# + (-0.3029574155807495+0j) * |10101011>
# + (0.2103017270565033+0j) * |10101101>
# + (-0.3029574155807495+0j) * |10101110>
# + (0.0223285723477602+0j) * |11001011>
# + (0.03624369949102402+0j) * |11001110>
# Energy eigenstate |E250> corresponds to eigenvalue: 7.236067771911621
# Representation in the computational basis:
# (0.18587356805801392+0j) * |01111011>
# + (-0.18587446212768555+0j) * |01111110>
# + (0.18587356805801392+0j) * |10110111>
# + (-0.601500928401947+0j) * |10111011>
# + (0.18587446212768555+0j) * |10111101>
# + (0.18587446212768555+0j) * |11011011>
# + (-0.18587356805801392+0j) * |11011110>
# + (-0.18587446212768555+0j) * |11100111>
# + (-0.18587356805801392+0j) * |11101101>
# + (0.601500928401947+0j) * |11101110>
# Energy eigenstate |E251> corresponds to eigenvalue: 7.236067771911621
# Representation in the computational basis:
# (-0.601500928401947+0j) * |01110111>
# + (0.18587446212768555+0j) * |01111011>
# + (0.18587356805801392+0j) * |01111110>
# + (0.18587446212768555+0j) * |10110111>
# + (-0.18587356805801392+0j) * |10111101>
# + (-0.18587356805801392+0j) * |11011011>
# + (0.601500928401947+0j) * |11011101>
# + (-0.18587446212768555+0j) * |11011110>
# + (0.18587356805801392+0j) * |11100111>
# + (-0.18587446212768555+0j) * |11101101>
# Energy eigenstate |E252> corresponds to eigenvalue: 8.0
# Representation in the computational basis:
# (-0.5+0j) * |01111111>
# + (0.5+0j) * |10111111>
# + (-0.5+0j) * |11011111>
# + (0.5+0j) * |11101111>
# Energy eigenstate |E253> corresponds to eigenvalue: 8.0
# Representation in the computational basis:
# (-0.5+0j) * |11110111>
# + (0.5+0j) * |11111011>
# + (-0.5+0j) * |11111101>
# + (0.5+0j) * |11111110>
# Energy eigenstate |E254> corresponds to eigenvalue: 8.0
# Representation in the computational basis:
# (1+0j) * |11111111>
# Energy eigenstate |E255> corresponds to eigenvalue: 8.685846328735352
# Representation in the computational basis:
# (-0.33480527997016907+0j) * |01110111>
# + (0.22480887174606323+0j) * |01111011>
# + (-0.19190460443496704+0j) * |01111101>
# + (0.22480887174606323+0j) * |01111110>
# + (0.22480887174606323+0j) * |10110111>
# + (-0.33480527997016907+0j) * |10111011>
# + (0.22480887174606323+0j) * |10111101>
# + (-0.19190460443496704+0j) * |10111110>
# + (-0.19190460443496704+0j) * |11010111>
# + (0.22480887174606323+0j) * |11011011>
# + (-0.33480527997016907+0j) * |11011101>
# + (0.22480887174606323+0j) * |11011110>
# + (0.22480887174606323+0j) * |11100111>
# + (-0.19190460443496704+0j) * |11101011>
# + (0.22480887174606323+0j) * |11101101>
# + (-0.33480527997016907+0j) * |11101110>

# %%
import numpy
import paddle_quantum
from paddle_quantum.qinfo import pauli_str_to_matrix

N = 8  # Number of qubits

# Pauli string representation of the total spin operator z-component
Sz_Pauli = [[0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.25, 'Z0,I1,I2,I3,I4,I5,I6,I7'], 
            [-0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [0.25, 'I0,I1,I2,I3,Z4,I5,I6,I7'], 
            [0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.25, 'I0,Z1,I2,I3,I4,I5,I6,I7'], 
            [-0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [0.25, 'I0,I1,I2,I3,I4,Z5,I6,I7'], 
            [0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.25, 'I0,I1,Z2,I3,I4,I5,I6,I7'], 
            [-0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [0.25, 'I0,I1,I2,I3,I4,I5,Z6,I7'], 
            [0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.25, 'I0,I1,I2,Z3,I4,I5,I6,I7'], 
            [-0.25, 'I0,I1,I2,I3,I4,I5,I6,I7'], [0.25, 'I0,I1,I2,I3,I4,I5,I6,Z7']]

# Define computational basis
basis = numpy.eye(2**N)

# Take the dagger
basis_dagger = numpy.array([numpy.conj(basis[i]).T for i in range(2**N)])

# Matrix form
Sz_matrix = pauli_str_to_matrix(Sz_Pauli, N).astype(paddle_quantum.get_dtype())

# Calculate the eigenvalues and eigenvectors of the Sz matrix
Sz_array = numpy.array(Sz_matrix)
eigenvalues, eigenvectors = numpy.linalg.eig(Sz_array)

# Express each eigenstate as a linear combination of computational basis states
for i in range(2**N):
    print(f"Sz eigenstate |Z{i}> corresponds to eigenvalue: {eigenvalues[i]}")
    print("Representation in the computational basis:")
    first = True   # Set the first nonzero term without a plus sign
    for j in range(2**N):
        coefficient = numpy.dot(basis_dagger[j], eigenvectors[i])
        if coefficient != 0:
            if first:
                print(f"{coefficient} * |{format(j, f'0{N}b')}>")
                first = False
            else:
                print(f"+ {coefficient} * |{format(j, f'0{N}b')}>")
# Out:
# Sz eigenstate |Z0> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00000000>
# Sz eigenstate |Z1> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00000001>
# Sz eigenstate |Z2> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00000010>
# Sz eigenstate |Z3> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00000011>
# Sz eigenstate |Z4> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00000100>
# Sz eigenstate |Z5> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00000101>
# Sz eigenstate |Z6> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00000110>
# Sz eigenstate |Z7> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00000111>
# Sz eigenstate |Z8> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00001000>
# Sz eigenstate |Z9> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00001001>
# Sz eigenstate |Z10> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00001010>
# Sz eigenstate |Z11> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00001011>
# Sz eigenstate |Z12> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00001100>
# Sz eigenstate |Z13> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00001101>
# Sz eigenstate |Z14> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00001110>
# Sz eigenstate |Z15> corresponds to eigenvalue: (-2+0j)
# Representation in the computational basis:
# (1+0j) * |00001111>
# Sz eigenstate |Z16> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00010000>
# Sz eigenstate |Z17> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00010001>
# Sz eigenstate |Z18> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00010010>
# Sz eigenstate |Z19> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00010011>
# Sz eigenstate |Z20> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00010100>
# Sz eigenstate |Z21> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00010101>
# Sz eigenstate |Z22> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00010110>
# Sz eigenstate |Z23> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00010111>
# Sz eigenstate |Z24> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00011000>
# Sz eigenstate |Z25> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00011001>
# Sz eigenstate |Z26> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00011010>
# Sz eigenstate |Z27> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00011011>
# Sz eigenstate |Z28> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00011100>
# Sz eigenstate |Z29> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00011101>
# Sz eigenstate |Z30> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00011110>
# Sz eigenstate |Z31> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00011111>
# Sz eigenstate |Z32> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00100000>
# Sz eigenstate |Z33> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00100001>
# Sz eigenstate |Z34> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00100010>
# Sz eigenstate |Z35> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00100011>
# Sz eigenstate |Z36> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00100100>
# Sz eigenstate |Z37> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00100101>
# Sz eigenstate |Z38> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00100110>
# Sz eigenstate |Z39> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00100111>
# Sz eigenstate |Z40> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00101000>
# Sz eigenstate |Z41> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00101001>
# Sz eigenstate |Z42> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00101010>
# Sz eigenstate |Z43> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00101011>
# Sz eigenstate |Z44> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00101100>
# Sz eigenstate |Z45> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00101101>
# Sz eigenstate |Z46> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00101110>
# Sz eigenstate |Z47> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |00101111>
# Sz eigenstate |Z48> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00110000>
# Sz eigenstate |Z49> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00110001>
# Sz eigenstate |Z50> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00110010>
# Sz eigenstate |Z51> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00110011>
# Sz eigenstate |Z52> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00110100>
# Sz eigenstate |Z53> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00110101>
# Sz eigenstate |Z54> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00110110>
# Sz eigenstate |Z55> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00110111>
# Sz eigenstate |Z56> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00111000>
# Sz eigenstate |Z57> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00111001>
# Sz eigenstate |Z58> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00111010>
# Sz eigenstate |Z59> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00111011>
# Sz eigenstate |Z60> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00111100>
# Sz eigenstate |Z61> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00111101>
# Sz eigenstate |Z62> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |00111110>
# Sz eigenstate |Z63> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |00111111>
# Sz eigenstate |Z64> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01000000>
# Sz eigenstate |Z65> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01000001>
# Sz eigenstate |Z66> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01000010>
# Sz eigenstate |Z67> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01000011>
# Sz eigenstate |Z68> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01000100>
# Sz eigenstate |Z69> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01000101>
# Sz eigenstate |Z70> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01000110>
# Sz eigenstate |Z71> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01000111>
# Sz eigenstate |Z72> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01001000>
# Sz eigenstate |Z73> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01001001>
# Sz eigenstate |Z74> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01001010>
# Sz eigenstate |Z75> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01001011>
# Sz eigenstate |Z76> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01001100>
# Sz eigenstate |Z77> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01001101>
# Sz eigenstate |Z78> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01001110>
# Sz eigenstate |Z79> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |01001111>
# Sz eigenstate |Z80> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01010000>
# Sz eigenstate |Z81> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01010001>
# Sz eigenstate |Z82> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01010010>
# Sz eigenstate |Z83> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01010011>
# Sz eigenstate |Z84> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01010100>
# Sz eigenstate |Z85> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01010101>
# Sz eigenstate |Z86> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01010110>
# Sz eigenstate |Z87> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01010111>
# Sz eigenstate |Z88> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01011000>
# Sz eigenstate |Z89> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01011001>
# Sz eigenstate |Z90> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01011010>
# Sz eigenstate |Z91> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01011011>
# Sz eigenstate |Z92> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01011100>
# Sz eigenstate |Z93> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01011101>
# Sz eigenstate |Z94> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01011110>
# Sz eigenstate |Z95> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01011111>
# Sz eigenstate |Z96> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01100000>
# Sz eigenstate |Z97> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01100001>
# Sz eigenstate |Z98> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01100010>
# Sz eigenstate |Z99> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01100011>
# Sz eigenstate |Z100> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01100100>
# Sz eigenstate |Z101> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01100101>
# Sz eigenstate |Z102> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01100110>
# Sz eigenstate |Z103> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01100111>
# Sz eigenstate |Z104> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01101000>
# Sz eigenstate |Z105> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01101001>
# Sz eigenstate |Z106> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01101010>
# Sz eigenstate |Z107> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01101011>
# Sz eigenstate |Z108> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01101100>
# Sz eigenstate |Z109> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01101101>
# Sz eigenstate |Z110> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01101110>
# Sz eigenstate |Z111> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |01101111>
# Sz eigenstate |Z112> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |01110000>
# Sz eigenstate |Z113> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01110001>
# Sz eigenstate |Z114> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01110010>
# Sz eigenstate |Z115> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01110011>
# Sz eigenstate |Z116> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01110100>
# Sz eigenstate |Z117> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01110101>
# Sz eigenstate |Z118> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01110110>
# Sz eigenstate |Z119> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01110111>
# Sz eigenstate |Z120> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01111000>
# Sz eigenstate |Z121> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01111001>
# Sz eigenstate |Z122> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01111010>
# Sz eigenstate |Z123> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01111011>
# Sz eigenstate |Z124> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01111100>
# Sz eigenstate |Z125> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01111101>
# Sz eigenstate |Z126> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |01111110>
# Sz eigenstate |Z127> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |01111111>
# Sz eigenstate |Z128> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10000000>
# Sz eigenstate |Z129> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10000001>
# Sz eigenstate |Z130> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10000010>
# Sz eigenstate |Z131> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10000011>
# Sz eigenstate |Z132> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10000100>
# Sz eigenstate |Z133> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10000101>
# Sz eigenstate |Z134> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10000110>
# Sz eigenstate |Z135> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10000111>
# Sz eigenstate |Z136> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10001000>
# Sz eigenstate |Z137> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10001001>
# Sz eigenstate |Z138> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10001010>
# Sz eigenstate |Z139> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10001011>
# Sz eigenstate |Z140> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10001100>
# Sz eigenstate |Z141> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10001101>
# Sz eigenstate |Z142> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10001110>
# Sz eigenstate |Z143> corresponds to eigenvalue: (-1.5+0j)
# Representation in the computational basis:
# (1+0j) * |10001111>
# Sz eigenstate |Z144> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10010000>
# Sz eigenstate |Z145> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10010001>
# Sz eigenstate |Z146> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10010010>
# Sz eigenstate |Z147> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10010011>
# Sz eigenstate |Z148> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10010100>
# Sz eigenstate |Z149> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10010101>
# Sz eigenstate |Z150> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10010110>
# Sz eigenstate |Z151> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10010111>
# Sz eigenstate |Z152> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10011000>
# Sz eigenstate |Z153> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10011001>
# Sz eigenstate |Z154> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10011010>
# Sz eigenstate |Z155> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10011011>
# Sz eigenstate |Z156> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10011100>
# Sz eigenstate |Z157> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10011101>
# Sz eigenstate |Z158> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10011110>
# Sz eigenstate |Z159> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10011111>
# Sz eigenstate |Z160> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10100000>
# Sz eigenstate |Z161> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10100001>
# Sz eigenstate |Z162> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10100010>
# Sz eigenstate |Z163> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10100011>
# Sz eigenstate |Z164> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10100100>
# Sz eigenstate |Z165> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10100101>
# Sz eigenstate |Z166> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10100110>
# Sz eigenstate |Z167> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10100111>
# Sz eigenstate |Z168> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10101000>
# Sz eigenstate |Z169> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10101001>
# Sz eigenstate |Z170> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10101010>
# Sz eigenstate |Z171> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10101011>
# Sz eigenstate |Z172> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10101100>
# Sz eigenstate |Z173> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10101101>
# Sz eigenstate |Z174> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10101110>
# Sz eigenstate |Z175> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |10101111>
# Sz eigenstate |Z176> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |10110000>
# Sz eigenstate |Z177> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10110001>
# Sz eigenstate |Z178> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10110010>
# Sz eigenstate |Z179> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10110011>
# Sz eigenstate |Z180> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10110100>
# Sz eigenstate |Z181> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10110101>
# Sz eigenstate |Z182> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10110110>
# Sz eigenstate |Z183> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10110111>
# Sz eigenstate |Z184> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10111000>
# Sz eigenstate |Z185> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10111001>
# Sz eigenstate |Z186> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10111010>
# Sz eigenstate |Z187> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10111011>
# Sz eigenstate |Z188> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10111100>
# Sz eigenstate |Z189> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10111101>
# Sz eigenstate |Z190> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |10111110>
# Sz eigenstate |Z191> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |10111111>
# Sz eigenstate |Z192> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11000000>
# Sz eigenstate |Z193> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11000001>
# Sz eigenstate |Z194> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11000010>
# Sz eigenstate |Z195> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11000011>
# Sz eigenstate |Z196> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11000100>
# Sz eigenstate |Z197> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11000101>
# Sz eigenstate |Z198> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11000110>
# Sz eigenstate |Z199> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11000111>
# Sz eigenstate |Z200> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11001000>
# Sz eigenstate |Z201> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11001001>
# Sz eigenstate |Z202> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11001010>
# Sz eigenstate |Z203> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11001011>
# Sz eigenstate |Z204> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11001100>
# Sz eigenstate |Z205> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11001101>
# Sz eigenstate |Z206> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11001110>
# Sz eigenstate |Z207> corresponds to eigenvalue: (-1+0j)
# Representation in the computational basis:
# (1+0j) * |11001111>
# Sz eigenstate |Z208> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11010000>
# Sz eigenstate |Z209> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11010001>
# Sz eigenstate |Z210> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11010010>
# Sz eigenstate |Z211> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11010011>
# Sz eigenstate |Z212> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11010100>
# Sz eigenstate |Z213> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11010101>
# Sz eigenstate |Z214> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11010110>
# Sz eigenstate |Z215> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11010111>
# Sz eigenstate |Z216> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11011000>
# Sz eigenstate |Z217> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11011001>
# Sz eigenstate |Z218> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11011010>
# Sz eigenstate |Z219> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11011011>
# Sz eigenstate |Z220> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11011100>
# Sz eigenstate |Z221> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11011101>
# Sz eigenstate |Z222> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11011110>
# Sz eigenstate |Z223> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11011111>
# Sz eigenstate |Z224> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11100000>
# Sz eigenstate |Z225> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11100001>
# Sz eigenstate |Z226> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11100010>
# Sz eigenstate |Z227> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11100011>
# Sz eigenstate |Z228> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11100100>
# Sz eigenstate |Z229> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11100101>
# Sz eigenstate |Z230> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11100110>
# Sz eigenstate |Z231> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11100111>
# Sz eigenstate |Z232> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11101000>
# Sz eigenstate |Z233> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11101001>
# Sz eigenstate |Z234> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11101010>
# Sz eigenstate |Z235> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11101011>
# Sz eigenstate |Z236> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11101100>
# Sz eigenstate |Z237> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11101101>
# Sz eigenstate |Z238> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11101110>
# Sz eigenstate |Z239> corresponds to eigenvalue: (-0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11101111>
# Sz eigenstate |Z240> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |11110000>
# Sz eigenstate |Z241> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11110001>
# Sz eigenstate |Z242> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11110010>
# Sz eigenstate |Z243> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11110011>
# Sz eigenstate |Z244> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11110100>
# Sz eigenstate |Z245> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11110101>
# Sz eigenstate |Z246> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11110110>
# Sz eigenstate |Z247> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11110111>
# Sz eigenstate |Z248> corresponds to eigenvalue: (1.5+0j)
# Representation in the computational basis:
# (1+0j) * |11111000>
# Sz eigenstate |Z249> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11111001>
# Sz eigenstate |Z250> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11111010>
# Sz eigenstate |Z251> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11111011>
# Sz eigenstate |Z252> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |11111100>
# Sz eigenstate |Z253> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11111101>
# Sz eigenstate |Z254> corresponds to eigenvalue: (0.5+0j)
# Representation in the computational basis:
# (1+0j) * |11111110>
# Sz eigenstate |Z255> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |11111111>

# %%
import numpy
import paddle_quantum
from paddle_quantum.qinfo import pauli_str_to_matrix

N = 8  # Number of qubits

# Pauli string representation of the particle number operator
NumOp_Pauli = [[0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'Z0,I1,I2,I3,I4,I5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,I2,I3,Z4,I5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,Z1,I2,I3,I4,I5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,I2,I3,I4,Z5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,Z2,I3,I4,I5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,I2,I3,I4,I5,Z6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,I2,Z3,I4,I5,I6,I7'], 
            [0.5, 'I0,I1,I2,I3,I4,I5,I6,I7'], [-0.5, 'I0,I1,I2,I3,I4,I5,I6,Z7']]

# Define computational basis
basis = numpy.eye(2**N)

# Take the dagger
basis_dagger = numpy.array([numpy.conj(basis[i]).T for i in range(2**N)])

# Matrix form
NumOp_matrix = pauli_str_to_matrix(NumOp_Pauli, N).astype(paddle_quantum.get_dtype())

# Calculate the eigenvalues and eigenvectors of the NumOp matrix
NumOp_array = numpy.array(NumOp_matrix)
eigenvalues, eigenvectors = numpy.linalg.eig(NumOp_array)

# Express each eigenstate as a linear combination of computational basis states
for i in range(2**N):
    print(f"Particle number eigenstate |N{i}> corresponds to eigenvalue: {eigenvalues[i]}")
    print("Representation in the computational basis:")
    first = True   # Set the first nonzero term without a plus sign
    for j in range(2**N):
        coefficient = numpy.dot(basis_dagger[j], eigenvectors[i])
        if coefficient != 0:
            if first:
                print(f"{coefficient} * |{format(j, f'0{N}b')}>")
                first = False
            else:
                print(f"+ {coefficient} * |{format(j, f'0{N}b')}>")
# Out:
# Particle number eigenstate |N0> corresponds to eigenvalue: 0j
# Representation in the computational basis:
# (1+0j) * |00000000>
# Particle number eigenstate |N1> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00000001>
# Particle number eigenstate |N2> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00000010>
# Particle number eigenstate |N3> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00000011>
# Particle number eigenstate |N4> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00000100>
# Particle number eigenstate |N5> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00000101>
# Particle number eigenstate |N6> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00000110>
# Particle number eigenstate |N7> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00000111>
# Particle number eigenstate |N8> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00001000>
# Particle number eigenstate |N9> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00001001>
# Particle number eigenstate |N10> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00001010>
# Particle number eigenstate |N11> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00001011>
# Particle number eigenstate |N12> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00001100>
# Particle number eigenstate |N13> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00001101>
# Particle number eigenstate |N14> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00001110>
# Particle number eigenstate |N15> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00001111>
# Particle number eigenstate |N16> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00010000>
# Particle number eigenstate |N17> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00010001>
# Particle number eigenstate |N18> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00010010>
# Particle number eigenstate |N19> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00010011>
# Particle number eigenstate |N20> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00010100>
# Particle number eigenstate |N21> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00010101>
# Particle number eigenstate |N22> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00010110>
# Particle number eigenstate |N23> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00010111>
# Particle number eigenstate |N24> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00011000>
# Particle number eigenstate |N25> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00011001>
# Particle number eigenstate |N26> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00011010>
# Particle number eigenstate |N27> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00011011>
# Particle number eigenstate |N28> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00011100>
# Particle number eigenstate |N29> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00011101>
# Particle number eigenstate |N30> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00011110>
# Particle number eigenstate |N31> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00011111>
# Particle number eigenstate |N32> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |00100000>
# Particle number eigenstate |N33> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00100001>
# Particle number eigenstate |N34> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00100010>
# Particle number eigenstate |N35> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00100011>
# Particle number eigenstate |N36> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00100100>
# Particle number eigenstate |N37> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00100101>
# Particle number eigenstate |N38> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00100110>
# Particle number eigenstate |N39> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00100111>
# Particle number eigenstate |N40> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00101000>
# Particle number eigenstate |N41> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00101001>
# Particle number eigenstate |N42> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00101010>
# Particle number eigenstate |N43> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00101011>
# Particle number eigenstate |N44> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00101100>
# Particle number eigenstate |N45> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00101101>
# Particle number eigenstate |N46> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00101110>
# Particle number eigenstate |N47> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00101111>
# Particle number eigenstate |N48> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |00110000>
# Particle number eigenstate |N49> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00110001>
# Particle number eigenstate |N50> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00110010>
# Particle number eigenstate |N51> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00110011>
# Particle number eigenstate |N52> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00110100>
# Particle number eigenstate |N53> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00110101>
# Particle number eigenstate |N54> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00110110>
# Particle number eigenstate |N55> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00110111>
# Particle number eigenstate |N56> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |00111000>
# Particle number eigenstate |N57> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00111001>
# Particle number eigenstate |N58> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00111010>
# Particle number eigenstate |N59> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00111011>
# Particle number eigenstate |N60> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |00111100>
# Particle number eigenstate |N61> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00111101>
# Particle number eigenstate |N62> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |00111110>
# Particle number eigenstate |N63> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |00111111>
# Particle number eigenstate |N64> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |01000000>
# Particle number eigenstate |N65> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01000001>
# Particle number eigenstate |N66> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01000010>
# Particle number eigenstate |N67> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01000011>
# Particle number eigenstate |N68> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01000100>
# Particle number eigenstate |N69> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01000101>
# Particle number eigenstate |N70> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01000110>
# Particle number eigenstate |N71> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01000111>
# Particle number eigenstate |N72> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01001000>
# Particle number eigenstate |N73> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01001001>
# Particle number eigenstate |N74> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01001010>
# Particle number eigenstate |N75> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01001011>
# Particle number eigenstate |N76> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01001100>
# Particle number eigenstate |N77> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01001101>
# Particle number eigenstate |N78> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01001110>
# Particle number eigenstate |N79> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01001111>
# Particle number eigenstate |N80> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01010000>
# Particle number eigenstate |N81> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01010001>
# Particle number eigenstate |N82> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01010010>
# Particle number eigenstate |N83> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01010011>
# Particle number eigenstate |N84> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01010100>
# Particle number eigenstate |N85> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01010101>
# Particle number eigenstate |N86> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01010110>
# Particle number eigenstate |N87> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01010111>
# Particle number eigenstate |N88> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01011000>
# Particle number eigenstate |N89> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01011001>
# Particle number eigenstate |N90> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01011010>
# Particle number eigenstate |N91> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01011011>
# Particle number eigenstate |N92> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01011100>
# Particle number eigenstate |N93> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01011101>
# Particle number eigenstate |N94> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01011110>
# Particle number eigenstate |N95> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01011111>
# Particle number eigenstate |N96> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |01100000>
# Particle number eigenstate |N97> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01100001>
# Particle number eigenstate |N98> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01100010>
# Particle number eigenstate |N99> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01100011>
# Particle number eigenstate |N100> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01100100>
# Particle number eigenstate |N101> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01100101>
# Particle number eigenstate |N102> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01100110>
# Particle number eigenstate |N103> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01100111>
# Particle number eigenstate |N104> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01101000>
# Particle number eigenstate |N105> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01101001>
# Particle number eigenstate |N106> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01101010>
# Particle number eigenstate |N107> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01101011>
# Particle number eigenstate |N108> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01101100>
# Particle number eigenstate |N109> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01101101>
# Particle number eigenstate |N110> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01101110>
# Particle number eigenstate |N111> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01101111>
# Particle number eigenstate |N112> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |01110000>
# Particle number eigenstate |N113> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01110001>
# Particle number eigenstate |N114> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01110010>
# Particle number eigenstate |N115> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01110011>
# Particle number eigenstate |N116> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01110100>
# Particle number eigenstate |N117> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01110101>
# Particle number eigenstate |N118> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01110110>
# Particle number eigenstate |N119> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01110111>
# Particle number eigenstate |N120> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |01111000>
# Particle number eigenstate |N121> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01111001>
# Particle number eigenstate |N122> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01111010>
# Particle number eigenstate |N123> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01111011>
# Particle number eigenstate |N124> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |01111100>
# Particle number eigenstate |N125> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01111101>
# Particle number eigenstate |N126> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |01111110>
# Particle number eigenstate |N127> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |01111111>
# Particle number eigenstate |N128> corresponds to eigenvalue: (1+0j)
# Representation in the computational basis:
# (1+0j) * |10000000>
# Particle number eigenstate |N129> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10000001>
# Particle number eigenstate |N130> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10000010>
# Particle number eigenstate |N131> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10000011>
# Particle number eigenstate |N132> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10000100>
# Particle number eigenstate |N133> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10000101>
# Particle number eigenstate |N134> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10000110>
# Particle number eigenstate |N135> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10000111>
# Particle number eigenstate |N136> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10001000>
# Particle number eigenstate |N137> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10001001>
# Particle number eigenstate |N138> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10001010>
# Particle number eigenstate |N139> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10001011>
# Particle number eigenstate |N140> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10001100>
# Particle number eigenstate |N141> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10001101>
# Particle number eigenstate |N142> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10001110>
# Particle number eigenstate |N143> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10001111>
# Particle number eigenstate |N144> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10010000>
# Particle number eigenstate |N145> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10010001>
# Particle number eigenstate |N146> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10010010>
# Particle number eigenstate |N147> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10010011>
# Particle number eigenstate |N148> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10010100>
# Particle number eigenstate |N149> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10010101>
# Particle number eigenstate |N150> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10010110>
# Particle number eigenstate |N151> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10010111>
# Particle number eigenstate |N152> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10011000>
# Particle number eigenstate |N153> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10011001>
# Particle number eigenstate |N154> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10011010>
# Particle number eigenstate |N155> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10011011>
# Particle number eigenstate |N156> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10011100>
# Particle number eigenstate |N157> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10011101>
# Particle number eigenstate |N158> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10011110>
# Particle number eigenstate |N159> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10011111>
# Particle number eigenstate |N160> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |10100000>
# Particle number eigenstate |N161> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10100001>
# Particle number eigenstate |N162> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10100010>
# Particle number eigenstate |N163> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10100011>
# Particle number eigenstate |N164> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10100100>
# Particle number eigenstate |N165> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10100101>
# Particle number eigenstate |N166> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10100110>
# Particle number eigenstate |N167> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10100111>
# Particle number eigenstate |N168> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10101000>
# Particle number eigenstate |N169> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10101001>
# Particle number eigenstate |N170> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10101010>
# Particle number eigenstate |N171> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10101011>
# Particle number eigenstate |N172> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10101100>
# Particle number eigenstate |N173> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10101101>
# Particle number eigenstate |N174> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10101110>
# Particle number eigenstate |N175> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10101111>
# Particle number eigenstate |N176> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |10110000>
# Particle number eigenstate |N177> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10110001>
# Particle number eigenstate |N178> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10110010>
# Particle number eigenstate |N179> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10110011>
# Particle number eigenstate |N180> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10110100>
# Particle number eigenstate |N181> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10110101>
# Particle number eigenstate |N182> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10110110>
# Particle number eigenstate |N183> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10110111>
# Particle number eigenstate |N184> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |10111000>
# Particle number eigenstate |N185> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10111001>
# Particle number eigenstate |N186> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10111010>
# Particle number eigenstate |N187> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10111011>
# Particle number eigenstate |N188> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |10111100>
# Particle number eigenstate |N189> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10111101>
# Particle number eigenstate |N190> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |10111110>
# Particle number eigenstate |N191> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |10111111>
# Particle number eigenstate |N192> corresponds to eigenvalue: (2+0j)
# Representation in the computational basis:
# (1+0j) * |11000000>
# Particle number eigenstate |N193> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11000001>
# Particle number eigenstate |N194> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11000010>
# Particle number eigenstate |N195> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11000011>
# Particle number eigenstate |N196> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11000100>
# Particle number eigenstate |N197> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11000101>
# Particle number eigenstate |N198> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11000110>
# Particle number eigenstate |N199> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11000111>
# Particle number eigenstate |N200> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11001000>
# Particle number eigenstate |N201> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11001001>
# Particle number eigenstate |N202> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11001010>
# Particle number eigenstate |N203> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11001011>
# Particle number eigenstate |N204> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11001100>
# Particle number eigenstate |N205> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11001101>
# Particle number eigenstate |N206> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11001110>
# Particle number eigenstate |N207> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11001111>
# Particle number eigenstate |N208> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11010000>
# Particle number eigenstate |N209> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11010001>
# Particle number eigenstate |N210> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11010010>
# Particle number eigenstate |N211> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11010011>
# Particle number eigenstate |N212> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11010100>
# Particle number eigenstate |N213> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11010101>
# Particle number eigenstate |N214> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11010110>
# Particle number eigenstate |N215> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11010111>
# Particle number eigenstate |N216> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11011000>
# Particle number eigenstate |N217> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11011001>
# Particle number eigenstate |N218> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11011010>
# Particle number eigenstate |N219> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11011011>
# Particle number eigenstate |N220> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11011100>
# Particle number eigenstate |N221> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11011101>
# Particle number eigenstate |N222> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11011110>
# Particle number eigenstate |N223> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11011111>
# Particle number eigenstate |N224> corresponds to eigenvalue: (3+0j)
# Representation in the computational basis:
# (1+0j) * |11100000>
# Particle number eigenstate |N225> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11100001>
# Particle number eigenstate |N226> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11100010>
# Particle number eigenstate |N227> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11100011>
# Particle number eigenstate |N228> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11100100>
# Particle number eigenstate |N229> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11100101>
# Particle number eigenstate |N230> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11100110>
# Particle number eigenstate |N231> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11100111>
# Particle number eigenstate |N232> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11101000>
# Particle number eigenstate |N233> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11101001>
# Particle number eigenstate |N234> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11101010>
# Particle number eigenstate |N235> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11101011>
# Particle number eigenstate |N236> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11101100>
# Particle number eigenstate |N237> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11101101>
# Particle number eigenstate |N238> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11101110>
# Particle number eigenstate |N239> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11101111>
# Particle number eigenstate |N240> corresponds to eigenvalue: (4+0j)
# Representation in the computational basis:
# (1+0j) * |11110000>
# Particle number eigenstate |N241> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11110001>
# Particle number eigenstate |N242> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11110010>
# Particle number eigenstate |N243> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11110011>
# Particle number eigenstate |N244> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11110100>
# Particle number eigenstate |N245> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11110101>
# Particle number eigenstate |N246> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11110110>
# Particle number eigenstate |N247> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11110111>
# Particle number eigenstate |N248> corresponds to eigenvalue: (5+0j)
# Representation in the computational basis:
# (1+0j) * |11111000>
# Particle number eigenstate |N249> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11111001>
# Particle number eigenstate |N250> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11111010>
# Particle number eigenstate |N251> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11111011>
# Particle number eigenstate |N252> corresponds to eigenvalue: (6+0j)
# Representation in the computational basis:
# (1+0j) * |11111100>
# Particle number eigenstate |N253> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11111101>
# Particle number eigenstate |N254> corresponds to eigenvalue: (7+0j)
# Representation in the computational basis:
# (1+0j) * |11111110>
# Particle number eigenstate |N255> corresponds to eigenvalue: (8+0j)
# Representation in the computational basis:
# (1+0j) * |11111111>
